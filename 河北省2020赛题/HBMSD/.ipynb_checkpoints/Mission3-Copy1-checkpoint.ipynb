# %% [markdown]
# # 导入数据集

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv
f = open('data 3.csv',encoding='UTF-8')
names = ['Index_Num','starttime','resolution','speed','volume','occupancy']
# filename=input("文件名：")
# f=open(filename,encoding='UTF-8')
# names=['作业日期','ηCO','ηH2','TF(℃)','TC(℃)','mass','送风流量']
data=read_csv(f,names=names,header=1)
print(data)
# Out:
#       Index_Num                  starttime resolution  speed  volume  \
# 0             3        2011-03-01T00:05:00    0:05:00    NaN     NaN
# 1             5        2011-03-01T00:10:00    0:05:00    NaN     NaN
# 2             8        2011-03-01T00:15:00    0:05:00    NaN     NaN
# 3             9        2011-03-01T00:20:00    0:05:00    NaN     NaN
# 4            12        2011-03-01T00:25:00    0:05:00    NaN     NaN
# ...         ...                        ...        ...    ...     ...
# 8582      17169  2011-03-30T23:40:00-07:00    0:05:00    NaN     NaN
# 8583      17170  2011-03-30T23:45:00-07:00    0:05:00    NaN     NaN
# 8584      17172  2011-03-30T23:50:00-07:00    0:05:00    NaN     NaN
# 8585      17175  2011-03-30T23:55:00-07:00    0:05:00    NaN     NaN
# 8586      17177  2011-03-31T00:00:00-07:00    0:05:00    NaN     NaN
#
#       occupancy
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 8582        NaN
# 8583        NaN
# 8584        NaN
# 8585        NaN
# 8586        NaN
#
# [8587 rows x 6 columns]

# %% [markdown]
# # 先处理重复数据

# %%
print (data.isnull().any())   # 这是按照列统计的空值

print("***********************************************")
print (data[data.isnull().values==True]) #查看哪些值是空值
 
# 这里涉及到对空值的处理：删除还是替换然后还有填充（这里删除分为有一个空值删除还是有两个空值删除一行。替换可以用特定值替换或者是用平均值替换）
# tt.fillna(0,inplace=True)  # 根据本例的特点，空值可以填充0

print("***********************************************")

print(data.starttime.duplicated())
# Out:
# Index_Num     False
# starttime     False
# resolution    False
# speed          True
# volume         True
# occupancy      True
# dtype: bool
# ***********************************************
#       Index_Num                  starttime resolution  speed  volume  \
# 0             3        2011-03-01T00:05:00    0:05:00    NaN     NaN
# 0             3        2011-03-01T00:05:00    0:05:00    NaN     NaN
# 0             3        2011-03-01T00:05:00    0:05:00    NaN     NaN
# 1             5        2011-03-01T00:10:00    0:05:00    NaN     NaN
# 1             5        2011-03-01T00:10:00    0:05:00    NaN     NaN
# ...         ...                        ...        ...    ...     ...
# 8585      17175  2011-03-30T23:55:00-07:00    0:05:00    NaN     NaN
# 8585      17175  2011-03-30T23:55:00-07:00    0:05:00    NaN     NaN
# 8586      17177  2011-03-31T00:00:00-07:00    0:05:00    NaN     NaN
# 8586      17177  2011-03-31T00:00:00-07:00    0:05:00    NaN     NaN
# 8586      17177  2011-03-31T00:00:00-07:00    0:05:00    NaN     NaN
#
#       occupancy
# 0           NaN
# 0           NaN
# 0           NaN
# 1           NaN
# 1           NaN
# ...         ...
# 8585        NaN
# 8585        NaN
# 8586        NaN
# 8586        NaN
# 8586        NaN
#
# [7953 rows x 6 columns]
# ***********************************************
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8582    False
# 8583    False
# 8584    False
# 8585    False
# 8586    False
# Name: starttime, Length: 8587, dtype: bool

# %%
data.starttime.drop_duplicates(keep=False,inplace=True)
#  把重复的值全部删除
print(data[data.duplicated(keep=False)])
# 检验。现在没有重复值
# Out:
# Empty DataFrame
# Columns: [Index_Num, starttime, resolution, speed, volume, occupancy]
# Index: []

# %% [markdown]
# ## 现在处理缺省值

# %%
#https://blog.csdn.net/lwgkzl/article/details/80948548
for tup in data.itertuples():
#     print(tup[0],'-->',tup[1::],type(tup[1:]))
    if data.speed[tup] == nan:
        if tup == 1 :  #先给第一个缺省值赋值
            tmpcount = 0
            while data.speed[tup+tmpcount] == nan :
                tmpcount+=1
            data.speed[tup] = data.speed[tup+tmpcount]
        elif tup >2 and tup <= data.shape[0]: #或者使用 len(data)
            tmpcount = 0
            while data.speed[tup+tmpcount] == nan :
                tmpcount+=1
            data.speed[tup] = (data.speed[tup-1]+data.speed[tup+tmpcount])/2
        elif tup == data.shape[0]+1:
            data.speed[tup] = data.speed[tup-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-df9b84a4d446> in <module>
#       2 for tup in data.itertuples():
#       3 #     print(tup[0],'-->',tup[1::],type(tup[1:]))
# ----> 4     if data.speed[tup] == nan:
#       5         if tup == 1 :  #先给第一个缺省值赋值
#       6             tmpcount = 0
#
# C:\ProgramData\Anaconda3\envs\mathematical_modeling\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# C:\ProgramData\Anaconda3\envs\mathematical_modeling\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4402         k = self._convert_scalar_indexer(k, kind="getitem")
#    4403         try:
# -> 4404             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4405         except KeyError as e1:
#    4406             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: Pandas(Index=0, starttime='starttime', speed='speed', volume='volume', occupancy='occupancy')

# %%
#这里有个问题，就是当我们面临一大堆nan的时候，是否应该根据时间
#speed缺省值填补
count = 1
for count in range(data.shape[0]):
#     print(tup[0],'-->',tup[1::],type(tup[1:]))
    speedtmp = data.loc[count,["speed"]].values
#     print(speedtmp)
#     print(speedtmp.dtype)
    if pd.isnull(speedtmp) :
        if count == 1 :  #先给第一个缺省值赋值
            tmpcount = 0
            while pd.isnull(data.loc[count+tmpcount,["speed"]].values) :
                tmpcount+=1
            data.loc[count,["speed"]] = data.loc[count+tmpcount,["speed"]]
            print("speed第一行为空")
        elif count >2 and count <= data.shape[0]: #或者使用 len(data)
            tmpcount = 0
            
            while pd.isnull(data.loc[count+tmpcount,["speed"]].values) :
                tmpcount+=1
                if ((count+tmpcount) > (data.shape[0]-1)):
                    data.loc[count,["occupancy"]] = data.loc[count-1,["speed"]]
                    break
            if ((count+tmpcount) <= (data.shape[0]-1)):
                data.loc[count,["speed"]] = (data.loc[count-1,["speed"]].values.astype(float)+data.loc[count+tmpcount,["speed"]].values.astype(float))/2
            else :
                pass

            print(count ,"speed修改成功")
        elif count == data.shape[0]+1:
            data.loc[count,["speed"]] = data.loc[count-1,["speed"]]
            print("speed最后一行为空")
    else :
        pass
    
#volume缺省值填补
count = 1
for count in range(data.shape[0]):
#     print(tup[0],'-->',tup[1::],type(tup[1:]))
    volumetmp = data.loc[count,["volume"]].values
#     print(speedtmp)
#     print(speedtmp.dtype)
    if pd.isnull(volumetmp) :
        if count == 1 :  #先给第一个缺省值赋值
            tmpcount = 0
            while pd.isnull(data.loc[count+tmpcount,["volume"]].values) :
                tmpcount+=1
            data.loc[count,["volume"]] = data.loc[count+tmpcount,["volume"]]
            print("volume第一行为空")
        elif count >2 and count <= data.shape[0]: #或者使用 len(data)
            tmpcount = 0
            
            while pd.isnull(data.loc[count+tmpcount,["volume"]].values) :
                tmpcount+=1
                if ((count+tmpcount) > (data.shape[0]-1)):
                    data.loc[count,["volume"]] = data.loc[count-1,["volume"]]
                    break
            if ((count+tmpcount) <= (data.shape[0]-1)):
                data.loc[count,["volume"]] = (data.loc[count-1,["volume"]].values.astype(float)+data.loc[count+tmpcount,["volume"]].values.astype(float))/2
            else :
                pass
            
            print(count ,"volume修改成功")
        elif count == data.shape[0]+1:
            data.loc[count,["volume"]] = data.loc[count-1,["volume"]]
            print("volume最后一行为空")
    else :
        pass
    
#occupancy缺省值填补
count = 1
for count in range(data.shape[0]):
#     print(tup[0],'-->',tup[1::],type(tup[1:]))
    occupancytmp = data.loc[count,["occupancy"]].values
#     print(speedtmp)
#     print(speedtmp.dtype)
    if pd.isnull(occupancytmp) :
        if count == 1 :  #先给第一个缺省值赋值
            tmpcount = 0
            while pd.isnull(data.loc[count+tmpcount,["occupancy"]].values) :
                tmpcount+=1
            data.loc[count,["occupancy"]] = data.loc[count+tmpcount,["occupancy"]]
            print("occupancy第一行为空")
        elif count >2 and count <= (data.shape[0]-1): #或者使用 len(data)
            tmpcount = 0
            while pd.isnull(data.loc[count+tmpcount,["occupancy"]].values) :
                tmpcount+=1
                if ((count+tmpcount) > (data.shape[0]-1)):
                    data.loc[count,["occupancy"]] = data.loc[count-1,["occupancy"]]
                    break
            if ((count+tmpcount) <= (data.shape[0]-1)):
                data.loc[count,["occupancy"]] = (data.loc[count-1,["occupancy"]].values.astype(float)+data.loc[count+tmpcount,["occupancy"]].values.astype(float))/2
            else :
                pass
            
            print(count ,"occupancy修改成功")
        elif count == data.shape[0]+1:
            data.loc[count,["occupancy"]] = data.loc[count-1,["occupancy"]]
            print("occupancy最后一行为空")
    else :
        pass
    
print (data)
# Out:
# 3 speed修改成功
# 4 speed修改成功
# 5 speed修改成功
# 6 speed修改成功
# 7 speed修改成功
# 8 speed修改成功
# 9 speed修改成功
# 10 speed修改成功
# 11 speed修改成功
# 12 speed修改成功
# 13 speed修改成功
# 14 speed修改成功
# 15 speed修改成功
# 16 speed修改成功
# 17 speed修改成功
# 18 speed修改成功
# 19 speed修改成功
# 20 speed修改成功
# 21 speed修改成功
# 22 speed修改成功
# 23 speed修改成功
# 24 speed修改成功
# 25 speed修改成功
# 26 speed修改成功
# 27 speed修改成功
# 28 speed修改成功
# 29 speed修改成功
# 30 speed修改成功
# 31 speed修改成功
# 32 speed修改成功
# 33 speed修改成功
# 34 speed修改成功
# 35 speed修改成功
# 36 speed修改成功
# 37 speed修改成功
# 38 speed修改成功
# 39 speed修改成功
# 40 speed修改成功
# 41 speed修改成功
# 42 speed修改成功
# 43 speed修改成功
# 44 speed修改成功
# 45 speed修改成功
# 46 speed修改成功
# 47 speed修改成功
# 48 speed修改成功
# 49 speed修改成功
# 50 speed修改成功
# 51 speed修改成功
# 52 speed修改成功
# 53 speed修改成功
# 54 speed修改成功
# 55 speed修改成功
# 56 speed修改成功
# 57 speed修改成功
# 58 speed修改成功
# 59 speed修改成功
# 60 speed修改成功
# 61 speed修改成功
# 62 speed修改成功
# 63 speed修改成功
# 64 speed修改成功
# 65 speed修改成功
# 66 speed修改成功
# 67 speed修改成功
# 68 speed修改成功
# 69 speed修改成功
# 70 speed修改成功
# 71 speed修改成功
# 72 speed修改成功
# 73 speed修改成功
# 74 speed修改成功
# 75 speed修改成功
# 76 speed修改成功
# 77 speed修改成功
# 78 speed修改成功
# 79 speed修改成功
# 80 speed修改成功
# 81 speed修改成功
# 82 speed修改成功
# 83 speed修改成功
# 84 speed修改成功
# 85 speed修改成功
# 86 speed修改成功
# 87 speed修改成功
# 88 speed修改成功
# 89 speed修改成功
# 90 speed修改成功
# 91 speed修改成功
# 92 speed修改成功
# 93 speed修改成功
# 94 speed修改成功
# 95 speed修改成功
# 96 speed修改成功
# 97 speed修改成功
# 98 speed修改成功
# 99 speed修改成功
# 100 speed修改成功
# 101 speed修改成功
# 102 speed修改成功
# 103 speed修改成功
# 104 speed修改成功
# 105 speed修改成功
# 106 speed修改成功
# 107 speed修改成功
# 108 speed修改成功
# 109 speed修改成功
# 110 speed修改成功
# 111 speed修改成功
# 112 speed修改成功
# 113 speed修改成功
# 114 speed修改成功
# 115 speed修改成功
# 116 speed修改成功
# 117 speed修改成功
# 118 speed修改成功
# 119 speed修改成功
# 120 speed修改成功
# 121 speed修改成功
# 122 speed修改成功
# 123 speed修改成功
# 124 speed修改成功
# 125 speed修改成功
# 126 speed修改成功
# 127 speed修改成功
# 128 speed修改成功
# 129 speed修改成功
# 130 speed修改成功
# 131 speed修改成功
# 132 speed修改成功
# 133 speed修改成功
# 134 speed修改成功
# 135 speed修改成功
# 136 speed修改成功
# 137 speed修改成功
# 138 speed修改成功
# 139 speed修改成功
# 140 speed修改成功
# 141 speed修改成功
# 142 speed修改成功
# 143 speed修改成功
# 144 speed修改成功
# 145 speed修改成功
# 146 speed修改成功
# 147 speed修改成功
# 148 speed修改成功
# 149 speed修改成功
# 150 speed修改成功
# 151 speed修改成功
# 152 speed修改成功
# 153 speed修改成功
# 154 speed修改成功
# 155 speed修改成功
# 156 speed修改成功
# 157 speed修改成功
# 158 speed修改成功
# 159 speed修改成功
# 160 speed修改成功
# 161 speed修改成功
# 162 speed修改成功
# 163 speed修改成功
# 164 speed修改成功
# 165 speed修改成功
# 166 speed修改成功
# 167 speed修改成功
# 168 speed修改成功
# 169 speed修改成功
# 170 speed修改成功
# 171 speed修改成功
# 172 speed修改成功
# 173 speed修改成功
# 174 speed修改成功
# 175 speed修改成功
# 176 speed修改成功
# 177 speed修改成功
# 178 speed修改成功
# 179 speed修改成功
# 180 speed修改成功
# 181 speed修改成功
# 182 speed修改成功
# 183 speed修改成功
# 184 speed修改成功
# 185 speed修改成功
# 186 speed修改成功
# 187 speed修改成功
# 188 speed修改成功
# 189 speed修改成功
# 190 speed修改成功
# 191 speed修改成功
# 192 speed修改成功
# 193 speed修改成功
# 194 speed修改成功
# 195 speed修改成功
# 196 speed修改成功
# 197 speed修改成功
# 198 speed修改成功
# 199 speed修改成功
# 200 speed修改成功
# 201 speed修改成功
# 202 speed修改成功
# 203 speed修改成功
# 204 speed修改成功
# 205 speed修改成功
# 206 speed修改成功
# 207 speed修改成功
# 208 speed修改成功
# 209 speed修改成功
# 210 speed修改成功
# 211 speed修改成功
# 212 speed修改成功
# 213 speed修改成功
# 214 speed修改成功
# 215 speed修改成功
# 216 speed修改成功
# 217 speed修改成功
# 218 speed修改成功
# 219 speed修改成功
# 220 speed修改成功
# 221 speed修改成功
# 222 speed修改成功
# 223 speed修改成功
# 224 speed修改成功
# 225 speed修改成功
# 226 speed修改成功
# 227 speed修改成功
# 228 speed修改成功
# 229 speed修改成功
# 230 speed修改成功
# 231 speed修改成功
# 232 speed修改成功
# 233 speed修改成功
# 234 speed修改成功
# 235 speed修改成功
# 236 speed修改成功
# 237 speed修改成功
# 238 speed修改成功
# 239 speed修改成功
# 240 speed修改成功
# 241 speed修改成功
# 242 speed修改成功
# 243 speed修改成功
# 244 speed修改成功
# 245 speed修改成功
# 246 speed修改成功
# 247 speed修改成功
# 248 speed修改成功
# 249 speed修改成功
# 250 speed修改成功
# 251 speed修改成功
# 252 speed修改成功
# 253 speed修改成功
# 254 speed修改成功
# 255 speed修改成功
# 256 speed修改成功
# 257 speed修改成功
# 258 speed修改成功
# 259 speed修改成功
# 260 speed修改成功
# 261 speed修改成功
# 262 speed修改成功
# 263 speed修改成功
# 264 speed修改成功
# 265 speed修改成功
# 266 speed修改成功
# 267 speed修改成功
# 268 speed修改成功
# 269 speed修改成功
# 270 speed修改成功
# 271 speed修改成功
# 272 speed修改成功
# 273 speed修改成功
# 274 speed修改成功
# 275 speed修改成功
# 276 speed修改成功
# 277 speed修改成功
# 278 speed修改成功
# 279 speed修改成功
# 280 speed修改成功
# 281 speed修改成功
# 282 speed修改成功
# 283 speed修改成功
# 284 speed修改成功
# 285 speed修改成功
# 286 speed修改成功
# 8298 speed修改成功
# 8299 speed修改成功
# 8300 speed修改成功
# 8301 speed修改成功
# 8302 speed修改成功
# 8303 speed修改成功
# 8304 speed修改成功
# 8305 speed修改成功
# 8306 speed修改成功
# 8307 speed修改成功
# 8308 speed修改成功
# 8309 speed修改成功
# 8310 speed修改成功
# 8311 speed修改成功
# 8312 speed修改成功
# 8313 speed修改成功
# 8314 speed修改成功
# 8315 speed修改成功
# 8316 speed修改成功
# 8317 speed修改成功
# 8318 speed修改成功
# 8319 speed修改成功
# 8320 speed修改成功
# 8321 speed修改成功
# 8322 speed修改成功
# 8323 speed修改成功
# 8324 speed修改成功
# 8325 speed修改成功
# 8326 speed修改成功
# 8327 speed修改成功
# 8328 speed修改成功
# 8329 speed修改成功
# 8330 speed修改成功
# 8331 speed修改成功
# 8332 speed修改成功
# 8333 speed修改成功
# 8334 speed修改成功
# 8335 speed修改成功
# 8336 speed修改成功
# 8337 speed修改成功
# 8338 speed修改成功
# 8339 speed修改成功
# 8340 speed修改成功
# 8341 speed修改成功
# 8342 speed修改成功
# 8343 speed修改成功
# 8344 speed修改成功
# 8345 speed修改成功
# 8346 speed修改成功
# 8347 speed修改成功
# 8348 speed修改成功
# 8349 speed修改成功
# 8350 speed修改成功
# 8351 speed修改成功
# 8352 speed修改成功
# 8353 speed修改成功
# 8354 speed修改成功
# 8355 speed修改成功
# 8356 speed修改成功
# 8357 speed修改成功
# 8358 speed修改成功
# 8359 speed修改成功
# 8360 speed修改成功
# 8361 speed修改成功
# 8362 speed修改成功
# 8363 speed修改成功
# 8364 speed修改成功
# 8365 speed修改成功
# 8366 speed修改成功
# 8367 speed修改成功
# 8368 speed修改成功
# 8369 speed修改成功
# 8370 speed修改成功
# 8371 speed修改成功
# 8372 speed修改成功
# 8373 speed修改成功
# 8374 speed修改成功
# 8375 speed修改成功
# 8376 speed修改成功
# 8377 speed修改成功
# 8378 speed修改成功
# 8379 speed修改成功
# 8380 speed修改成功
# 8381 speed修改成功
# 8382 speed修改成功
# 8383 speed修改成功
# 8384 speed修改成功
# 8385 speed修改成功
# 8386 speed修改成功
# 8387 speed修改成功
# 8388 speed修改成功
# 8389 speed修改成功
# 8390 speed修改成功
# 8391 speed修改成功
# 8392 speed修改成功
# 8393 speed修改成功
# 8394 speed修改成功
# 8395 speed修改成功
# 8396 speed修改成功
# 8397 speed修改成功
# 8398 speed修改成功
# 8399 speed修改成功
# 8400 speed修改成功
# 8401 speed修改成功
# 8402 speed修改成功
# 8403 speed修改成功
# 8404 speed修改成功
# 8405 speed修改成功
# 8406 speed修改成功
# 8407 speed修改成功
# 8408 speed修改成功
# 8409 speed修改成功
# 8410 speed修改成功
# 8411 speed修改成功
# 8412 speed修改成功
# 8413 speed修改成功
# 8414 speed修改成功
# 8415 speed修改成功
# 8416 speed修改成功
# 8417 speed修改成功
# 8418 speed修改成功
# 8419 speed修改成功
# 8420 speed修改成功
# 8421 speed修改成功
# 8422 speed修改成功
# 8423 speed修改成功
# 8424 speed修改成功
# 8425 speed修改成功
# 8426 speed修改成功
# 8427 speed修改成功
# 8428 speed修改成功
# 8429 speed修改成功
# 8430 speed修改成功
# 8431 speed修改成功
# 8432 speed修改成功
# 8433 speed修改成功
# 8434 speed修改成功
# 8435 speed修改成功
# 8436 speed修改成功
# 8437 speed修改成功
# 8438 speed修改成功
# 8439 speed修改成功
# 8440 speed修改成功
# 8441 speed修改成功
# 8442 speed修改成功
# 8443 speed修改成功
# 8444 speed修改成功
# 8445 speed修改成功
# 8446 speed修改成功
# 8447 speed修改成功
# 8448 speed修改成功
# 8449 speed修改成功
# 8450 speed修改成功
# 8451 speed修改成功
# 8452 speed修改成功
# 8453 speed修改成功
# 8454 speed修改成功
# 8455 speed修改成功
# 8456 speed修改成功
# 8457 speed修改成功
# 8458 speed修改成功
# 8459 speed修改成功
# 8460 speed修改成功
# 8461 speed修改成功
# 8462 speed修改成功
# 8463 speed修改成功
# 8464 speed修改成功
# 8465 speed修改成功
# 8466 speed修改成功
# 8467 speed修改成功
# 8468 speed修改成功
# 8469 speed修改成功
# 8470 speed修改成功
# 8471 speed修改成功
# 8472 speed修改成功
# 8473 speed修改成功
# 8474 speed修改成功
# 8475 speed修改成功
# 8476 speed修改成功
# 8477 speed修改成功
# 8478 speed修改成功
# 8479 speed修改成功
# 8480 speed修改成功
# 8481 speed修改成功
# 8482 speed修改成功
# 8483 speed修改成功
# 8484 speed修改成功
# 8485 speed修改成功
# 8486 speed修改成功
# 8487 speed修改成功
# 8488 speed修改成功
# 8489 speed修改成功
# 8490 speed修改成功
# 8491 speed修改成功
# 8492 speed修改成功
# 8493 speed修改成功
# 8494 speed修改成功
# 8495 speed修改成功
# 8496 speed修改成功
# 8497 speed修改成功
# 8498 speed修改成功
# 8499 speed修改成功
# 8500 speed修改成功
# 8501 speed修改成功
# 8502 speed修改成功
# 8503 speed修改成功
# 8504 speed修改成功
# 8505 speed修改成功
# 8506 speed修改成功
# 8507 speed修改成功
# 8508 speed修改成功
# 8509 speed修改成功
# 8510 speed修改成功
# 8511 speed修改成功
# 8512 speed修改成功
# 8513 speed修改成功
# 8514 speed修改成功
# 8515 speed修改成功
# 8516 speed修改成功
# 8517 speed修改成功
# 8518 speed修改成功
# 8519 speed修改成功
# 8520 speed修改成功
# 8521 speed修改成功
# 8522 speed修改成功
# 8523 speed修改成功
# 8524 speed修改成功
# 8525 speed修改成功
# 8526 speed修改成功
# 8527 speed修改成功
# 8528 speed修改成功
# 8529 speed修改成功
# 8530 speed修改成功
# 8531 speed修改成功
# 8532 speed修改成功
# 8533 speed修改成功
# 8534 speed修改成功
# 8535 speed修改成功
# 8536 speed修改成功
# 8537 speed修改成功
# 8538 speed修改成功
# 8539 speed修改成功
# 8540 speed修改成功
# 8541 speed修改成功
# 8542 speed修改成功
# 8543 speed修改成功
# 8544 speed修改成功
# 8545 speed修改成功
# 8546 speed修改成功
# 8547 speed修改成功
# 8548 speed修改成功
# 8549 speed修改成功
# 8550 speed修改成功
# 8551 speed修改成功
# 8552 speed修改成功
# 8553 speed修改成功
# 8554 speed修改成功
# 8555 speed修改成功
# 8556 speed修改成功
# 8557 speed修改成功
# 8558 speed修改成功
# 8559 speed修改成功
# 8560 speed修改成功
# 8561 speed修改成功
# 8562 speed修改成功
# 8563 speed修改成功
# 8564 speed修改成功
# 8565 speed修改成功
# 8566 speed修改成功
# 8567 speed修改成功
# 8568 speed修改成功
# 8569 speed修改成功
# 8570 speed修改成功
# 8571 speed修改成功
# 8572 speed修改成功
# 8573 speed修改成功
# 8574 speed修改成功
# 8575 speed修改成功
# 8576 speed修改成功
# 8577 speed修改成功
# 8578 speed修改成功
# 8579 speed修改成功
# 8580 speed修改成功
# 8581 speed修改成功
# 8582 speed修改成功
# 8583 speed修改成功
# 8584 speed修改成功
# 8585 speed修改成功
# 8586 speed修改成功
# volume第一行为空
# 3 volume修改成功
# 4 volume修改成功
# 5 volume修改成功
# 6 volume修改成功
# 7 volume修改成功
# 8 volume修改成功
# 9 volume修改成功
# 10 volume修改成功
# 11 volume修改成功
# 12 volume修改成功
# 13 volume修改成功
# 14 volume修改成功
# 15 volume修改成功
# 16 volume修改成功
# 17 volume修改成功
# 18 volume修改成功
# 19 volume修改成功
# 20 volume修改成功
# 21 volume修改成功
# 22 volume修改成功
# 23 volume修改成功
# 24 volume修改成功
# 25 volume修改成功
# 26 volume修改成功
# 27 volume修改成功
# 28 volume修改成功
# 29 volume修改成功
# 30 volume修改成功
# 31 volume修改成功
# 32 volume修改成功
# 33 volume修改成功
# 34 volume修改成功
# 35 volume修改成功
# 36 volume修改成功
# 37 volume修改成功
# 38 volume修改成功
# 39 volume修改成功
# 40 volume修改成功
# 41 volume修改成功
# 42 volume修改成功
# 43 volume修改成功
# 44 volume修改成功
# 45 volume修改成功
# 46 volume修改成功
# 47 volume修改成功
# 48 volume修改成功
# 49 volume修改成功
# 50 volume修改成功
# 51 volume修改成功
# 52 volume修改成功
# 53 volume修改成功
# 54 volume修改成功
# 55 volume修改成功
# 56 volume修改成功
# 57 volume修改成功
# 58 volume修改成功
# 59 volume修改成功
# 60 volume修改成功
# 61 volume修改成功
# 62 volume修改成功
# 63 volume修改成功
# 64 volume修改成功
# 65 volume修改成功
# 66 volume修改成功
# 67 volume修改成功
# 68 volume修改成功
# 69 volume修改成功
# 70 volume修改成功
# 71 volume修改成功
# 72 volume修改成功
# 73 volume修改成功
# 74 volume修改成功
# 75 volume修改成功
# 76 volume修改成功
# 77 volume修改成功
# 78 volume修改成功
# 79 volume修改成功
# 80 volume修改成功
# 81 volume修改成功
# 82 volume修改成功
# 83 volume修改成功
# 84 volume修改成功
# 85 volume修改成功
# 86 volume修改成功
# 87 volume修改成功
# 88 volume修改成功
# 89 volume修改成功
# 90 volume修改成功
# 91 volume修改成功
# 92 volume修改成功
# 93 volume修改成功
# 94 volume修改成功
# 95 volume修改成功
# 96 volume修改成功
# 97 volume修改成功
# 98 volume修改成功
# 99 volume修改成功
# 100 volume修改成功
# 101 volume修改成功
# 102 volume修改成功
# 103 volume修改成功
# 104 volume修改成功
# 105 volume修改成功
# 106 volume修改成功
# 107 volume修改成功
# 108 volume修改成功
# 109 volume修改成功
# 110 volume修改成功
# 111 volume修改成功
# 112 volume修改成功
# 113 volume修改成功
# 114 volume修改成功
# 115 volume修改成功
# 116 volume修改成功
# 117 volume修改成功
# 118 volume修改成功
# 119 volume修改成功
# 120 volume修改成功
# 121 volume修改成功
# 122 volume修改成功
# 123 volume修改成功
# 124 volume修改成功
# 125 volume修改成功
# 126 volume修改成功
# 127 volume修改成功
# 128 volume修改成功
# 129 volume修改成功
# 130 volume修改成功
# 131 volume修改成功
# 132 volume修改成功
# 133 volume修改成功
# 134 volume修改成功
# 135 volume修改成功
# 136 volume修改成功
# 137 volume修改成功
# 138 volume修改成功
# 139 volume修改成功
# 140 volume修改成功
# 141 volume修改成功
# 142 volume修改成功
# 143 volume修改成功
# 144 volume修改成功
# 145 volume修改成功
# 146 volume修改成功
# 147 volume修改成功
# 148 volume修改成功
# 149 volume修改成功
# 150 volume修改成功
# 151 volume修改成功
# 152 volume修改成功
# 153 volume修改成功
# 154 volume修改成功
# 155 volume修改成功
# 156 volume修改成功
# 157 volume修改成功
# 158 volume修改成功
# 159 volume修改成功
# 160 volume修改成功
# 161 volume修改成功
# 162 volume修改成功
# 163 volume修改成功
# 164 volume修改成功
# 165 volume修改成功
# 166 volume修改成功
# 167 volume修改成功
# 168 volume修改成功
# 169 volume修改成功
# 170 volume修改成功
# 171 volume修改成功
# 172 volume修改成功
# 173 volume修改成功
# 174 volume修改成功
# 175 volume修改成功
# 176 volume修改成功
# 177 volume修改成功
# 178 volume修改成功
# 179 volume修改成功
# 180 volume修改成功
# 181 volume修改成功
# 182 volume修改成功
# 183 volume修改成功
# 184 volume修改成功
# 185 volume修改成功
# 186 volume修改成功
# 187 volume修改成功
# 188 volume修改成功
# 189 volume修改成功
# 190 volume修改成功
# 191 volume修改成功
# 192 volume修改成功
# 193 volume修改成功
# 194 volume修改成功
# 195 volume修改成功
# 196 volume修改成功
# 197 volume修改成功
# 198 volume修改成功
# 199 volume修改成功
# 200 volume修改成功
# 201 volume修改成功
# 202 volume修改成功
# 203 volume修改成功
# 204 volume修改成功
# 205 volume修改成功
# 206 volume修改成功
# 207 volume修改成功
# 208 volume修改成功
# 209 volume修改成功
# 210 volume修改成功
# 211 volume修改成功
# 212 volume修改成功
# 213 volume修改成功
# 214 volume修改成功
# 215 volume修改成功
# 216 volume修改成功
# 217 volume修改成功
# 218 volume修改成功
# 219 volume修改成功
# 220 volume修改成功
# 221 volume修改成功
# 222 volume修改成功
# 223 volume修改成功
# 224 volume修改成功
# 225 volume修改成功
# 226 volume修改成功
# 227 volume修改成功
# 228 volume修改成功
# 229 volume修改成功
# 230 volume修改成功
# 231 volume修改成功
# 232 volume修改成功
# 233 volume修改成功
# 234 volume修改成功
# 235 volume修改成功
# 236 volume修改成功
# 237 volume修改成功
# 238 volume修改成功
# 239 volume修改成功
# 240 volume修改成功
# 241 volume修改成功
# 242 volume修改成功
# 243 volume修改成功
# 244 volume修改成功
# 245 volume修改成功
# 246 volume修改成功
# 247 volume修改成功
# 248 volume修改成功
# 249 volume修改成功
# 250 volume修改成功
# 251 volume修改成功
# 252 volume修改成功
# 253 volume修改成功
# 254 volume修改成功
# 255 volume修改成功
# 256 volume修改成功
# 257 volume修改成功
# 258 volume修改成功
# 259 volume修改成功
# 260 volume修改成功
# 261 volume修改成功
# 262 volume修改成功
# 263 volume修改成功
# 264 volume修改成功
# 265 volume修改成功
# 266 volume修改成功
# 267 volume修改成功
# 268 volume修改成功
# 269 volume修改成功
# 270 volume修改成功
# 271 volume修改成功
# 272 volume修改成功
# 273 volume修改成功
# 274 volume修改成功
# 275 volume修改成功
# 276 volume修改成功
# 277 volume修改成功
# 278 volume修改成功
# 279 volume修改成功
# 280 volume修改成功
# 281 volume修改成功
# 282 volume修改成功
# 283 volume修改成功
# 284 volume修改成功
# 285 volume修改成功
# 286 volume修改成功
# 863 volume修改成功
# 864 volume修改成功
# 865 volume修改成功
# 866 volume修改成功
# 867 volume修改成功
# 868 volume修改成功
# 869 volume修改成功
# 870 volume修改成功
# 871 volume修改成功
# 872 volume修改成功
# 873 volume修改成功
# 874 volume修改成功
# 875 volume修改成功
# 876 volume修改成功
# 877 volume修改成功
# 878 volume修改成功
# 879 volume修改成功
# 880 volume修改成功
# 881 volume修改成功
# 882 volume修改成功
# 883 volume修改成功
# 884 volume修改成功
# 885 volume修改成功
# 886 volume修改成功
# 887 volume修改成功
# 888 volume修改成功
# 889 volume修改成功
# 890 volume修改成功
# 891 volume修改成功
# 892 volume修改成功
# 893 volume修改成功
# 894 volume修改成功
# 895 volume修改成功
# 896 volume修改成功
# 897 volume修改成功
# 898 volume修改成功
# 899 volume修改成功
# 900 volume修改成功
# 901 volume修改成功
# 902 volume修改成功
# 903 volume修改成功
# 904 volume修改成功
# 905 volume修改成功
# 906 volume修改成功
# 907 volume修改成功
# 908 volume修改成功
# 909 volume修改成功
# 910 volume修改成功
# 911 volume修改成功
# 912 volume修改成功
# 913 volume修改成功
# 914 volume修改成功
# 915 volume修改成功
# 916 volume修改成功
# 917 volume修改成功
# 918 volume修改成功
# 919 volume修改成功
# 920 volume修改成功
# 921 volume修改成功
# 922 volume修改成功
# 923 volume修改成功
# 924 volume修改成功
# 925 volume修改成功
# 926 volume修改成功
# 927 volume修改成功
# 928 volume修改成功
# 929 volume修改成功
# 930 volume修改成功
# 931 volume修改成功
# 932 volume修改成功
# 933 volume修改成功
# 934 volume修改成功
# 935 volume修改成功
# 936 volume修改成功
# 937 volume修改成功
# 938 volume修改成功
# 939 volume修改成功
# 940 volume修改成功
# 941 volume修改成功
# 942 volume修改成功
# 943 volume修改成功
# 944 volume修改成功
# 945 volume修改成功
# 946 volume修改成功
# 947 volume修改成功
# 948 volume修改成功
# 949 volume修改成功
# 950 volume修改成功
# 951 volume修改成功
# 952 volume修改成功
# 953 volume修改成功
# 954 volume修改成功
# 955 volume修改成功
# 956 volume修改成功
# 957 volume修改成功
# 958 volume修改成功
# 959 volume修改成功
# 960 volume修改成功
# 961 volume修改成功
# 962 volume修改成功
# 963 volume修改成功
# 964 volume修改成功
# 965 volume修改成功
# 966 volume修改成功
# 967 volume修改成功
# 968 volume修改成功
# 969 volume修改成功
# 970 volume修改成功
# 971 volume修改成功
# 972 volume修改成功
# 973 volume修改成功
# 974 volume修改成功
# 975 volume修改成功
# 976 volume修改成功
# 977 volume修改成功
# 978 volume修改成功
# 979 volume修改成功
# 980 volume修改成功
# 981 volume修改成功
# 982 volume修改成功
# 983 volume修改成功
# 984 volume修改成功
# 985 volume修改成功
# 986 volume修改成功
# 987 volume修改成功
# 988 volume修改成功
# 989 volume修改成功
# 990 volume修改成功
# 991 volume修改成功
# 992 volume修改成功
# 993 volume修改成功
# 994 volume修改成功
# 995 volume修改成功
# 996 volume修改成功
# 997 volume修改成功
# 998 volume修改成功
# 999 volume修改成功
# 1000 volume修改成功
# 1001 volume修改成功
# 1002 volume修改成功
# 1003 volume修改成功
# 1004 volume修改成功
# 1005 volume修改成功
# 1006 volume修改成功
# 1007 volume修改成功
# 1008 volume修改成功
# 1009 volume修改成功
# 1010 volume修改成功
# 1011 volume修改成功
# 1012 volume修改成功
# 1013 volume修改成功
# 1014 volume修改成功
# 1015 volume修改成功
# 1016 volume修改成功
# 1017 volume修改成功
# 1018 volume修改成功
# 1019 volume修改成功
# 1020 volume修改成功
# 1021 volume修改成功
# 1022 volume修改成功
# 1023 volume修改成功
# 1024 volume修改成功
# 1025 volume修改成功
# 1026 volume修改成功
# 1027 volume修改成功
# 1028 volume修改成功
# 1029 volume修改成功
# 1030 volume修改成功
# 1031 volume修改成功
# 1032 volume修改成功
# 1033 volume修改成功
# 1034 volume修改成功
# 1035 volume修改成功
# 1036 volume修改成功
# 1037 volume修改成功
# 1038 volume修改成功
# 1039 volume修改成功
# 1040 volume修改成功
# 1041 volume修改成功
# 1042 volume修改成功
# 1043 volume修改成功
# 1044 volume修改成功
# 1045 volume修改成功
# 1046 volume修改成功
# 1047 volume修改成功
# 1048 volume修改成功
# 1049 volume修改成功
# 1050 volume修改成功
# 1051 volume修改成功
# 1052 volume修改成功
# 1053 volume修改成功
# 1054 volume修改成功
# 1055 volume修改成功
# 1056 volume修改成功
# 1057 volume修改成功
# 1058 volume修改成功
# 1059 volume修改成功
# 1060 volume修改成功
# 1061 volume修改成功
# 1062 volume修改成功
# 1063 volume修改成功
# 1064 volume修改成功
# 1065 volume修改成功
# 1066 volume修改成功
# 1067 volume修改成功
# 1068 volume修改成功
# 1069 volume修改成功
# 1070 volume修改成功
# 1071 volume修改成功
# 1072 volume修改成功
# 1073 volume修改成功
# 1074 volume修改成功
# 1075 volume修改成功
# 1076 volume修改成功
# 1077 volume修改成功
# 1078 volume修改成功
# 1079 volume修改成功
# 1080 volume修改成功
# 1081 volume修改成功
# 1082 volume修改成功
# 1083 volume修改成功
# 1084 volume修改成功
# 1085 volume修改成功
# 1086 volume修改成功
# 1087 volume修改成功
# 1088 volume修改成功
# 1089 volume修改成功
# 1090 volume修改成功
# 1091 volume修改成功
# 1092 volume修改成功
# 1093 volume修改成功
# 1094 volume修改成功
# 1095 volume修改成功
# 1096 volume修改成功
# 1097 volume修改成功
# 1098 volume修改成功
# 1099 volume修改成功
# 1100 volume修改成功
# 1101 volume修改成功
# 1102 volume修改成功
# 1103 volume修改成功
# 1104 volume修改成功
# 1105 volume修改成功
# 1106 volume修改成功
# 1107 volume修改成功
# 1108 volume修改成功
# 1109 volume修改成功
# 1110 volume修改成功
# 1111 volume修改成功
# 1112 volume修改成功
# 1113 volume修改成功
# 1114 volume修改成功
# 1115 volume修改成功
# 1116 volume修改成功
# 1117 volume修改成功
# 1118 volume修改成功
# 1119 volume修改成功
# 1120 volume修改成功
# 1121 volume修改成功
# 1122 volume修改成功
# 1123 volume修改成功
# 1124 volume修改成功
# 1125 volume修改成功
# 1126 volume修改成功
# 1127 volume修改成功
# 1128 volume修改成功
# 1129 volume修改成功
# 1130 volume修改成功
# 1131 volume修改成功
# 1132 volume修改成功
# 1133 volume修改成功
# 1134 volume修改成功
# 1135 volume修改成功
# 1136 volume修改成功
# 1137 volume修改成功
# 1138 volume修改成功
# 1139 volume修改成功
# 1140 volume修改成功
# 1141 volume修改成功
# 1142 volume修改成功
# 1143 volume修改成功
# 1144 volume修改成功
# 1145 volume修改成功
# 1146 volume修改成功
# 1147 volume修改成功
# 1148 volume修改成功
# 1149 volume修改成功
# 1150 volume修改成功
# 1151 volume修改成功
# 1152 volume修改成功
# 1153 volume修改成功
# 1154 volume修改成功
# 1155 volume修改成功
# 1156 volume修改成功
# 1157 volume修改成功
# 1158 volume修改成功
# 1159 volume修改成功
# 1160 volume修改成功
# 1161 volume修改成功
# 1162 volume修改成功
# 1163 volume修改成功
# 1164 volume修改成功
# 1165 volume修改成功
# 1166 volume修改成功
# 1167 volume修改成功
# 1168 volume修改成功
# 1169 volume修改成功
# 1170 volume修改成功
# 1171 volume修改成功
# 1172 volume修改成功
# 1173 volume修改成功
# 1174 volume修改成功
# 1175 volume修改成功
# 1176 volume修改成功
# 1177 volume修改成功
# 1178 volume修改成功
# 1179 volume修改成功
# 1180 volume修改成功
# 1181 volume修改成功
# 1182 volume修改成功
# 1183 volume修改成功
# 1184 volume修改成功
# 1185 volume修改成功
# 1186 volume修改成功
# 1187 volume修改成功
# 1188 volume修改成功
# 1189 volume修改成功
# 1190 volume修改成功
# 1191 volume修改成功
# 1192 volume修改成功
# 1193 volume修改成功
# 1194 volume修改成功
# 1195 volume修改成功
# 1196 volume修改成功
# 1197 volume修改成功
# 1198 volume修改成功
# 1199 volume修改成功
# 1200 volume修改成功
# 1201 volume修改成功
# 1202 volume修改成功
# 1203 volume修改成功
# 1204 volume修改成功
# 1205 volume修改成功
# 1206 volume修改成功
# 1207 volume修改成功
# 1208 volume修改成功
# 1209 volume修改成功
# 1210 volume修改成功
# 1211 volume修改成功
# 1212 volume修改成功
# 1213 volume修改成功
# 1214 volume修改成功
# 1215 volume修改成功
# 1216 volume修改成功
# 1217 volume修改成功
# 1218 volume修改成功
# 1219 volume修改成功
# 1220 volume修改成功
# 1221 volume修改成功
# 1222 volume修改成功
# 1223 volume修改成功
# 1224 volume修改成功
# 1225 volume修改成功
# 1226 volume修改成功
# 1227 volume修改成功
# 1228 volume修改成功
# 1229 volume修改成功
# 1230 volume修改成功
# 1231 volume修改成功
# 1232 volume修改成功
# 1233 volume修改成功
# 1234 volume修改成功
# 1235 volume修改成功
# 1236 volume修改成功
# 1237 volume修改成功
# 1238 volume修改成功
# 1239 volume修改成功
# 1240 volume修改成功
# 1241 volume修改成功
# 1242 volume修改成功
# 1243 volume修改成功
# 1244 volume修改成功
# 1245 volume修改成功
# 1246 volume修改成功
# 1247 volume修改成功
# 1248 volume修改成功
# 1249 volume修改成功
# 1250 volume修改成功
# 1251 volume修改成功
# 1252 volume修改成功
# 1253 volume修改成功
# 1254 volume修改成功
# 1255 volume修改成功
# 1256 volume修改成功
# 1257 volume修改成功
# 1258 volume修改成功
# 1259 volume修改成功
# 1260 volume修改成功
# 1261 volume修改成功
# 1262 volume修改成功
# 1263 volume修改成功
# 1264 volume修改成功
# 1265 volume修改成功
# 1266 volume修改成功
# 1267 volume修改成功
# 1268 volume修改成功
# 1269 volume修改成功
# 1270 volume修改成功
# 1271 volume修改成功
# 1272 volume修改成功
# 1273 volume修改成功
# 1274 volume修改成功
# 1275 volume修改成功
# 1276 volume修改成功
# 1277 volume修改成功
# 1278 volume修改成功
# 1279 volume修改成功
# 1280 volume修改成功
# 1281 volume修改成功
# 1282 volume修改成功
# 1283 volume修改成功
# 1284 volume修改成功
# 1285 volume修改成功
# 1286 volume修改成功
# 1287 volume修改成功
# 1288 volume修改成功
# 1289 volume修改成功
# 1290 volume修改成功
# 1291 volume修改成功
# 1292 volume修改成功
# 1293 volume修改成功
# 1294 volume修改成功
# 1295 volume修改成功
# 1296 volume修改成功
# 1297 volume修改成功
# 1298 volume修改成功
# 1299 volume修改成功
# 1300 volume修改成功
# 1301 volume修改成功
# 1302 volume修改成功
# 1303 volume修改成功
# 1304 volume修改成功
# 1305 volume修改成功
# 1306 volume修改成功
# 1307 volume修改成功
# 1308 volume修改成功
# 1309 volume修改成功
# 1310 volume修改成功
# 1311 volume修改成功
# 1312 volume修改成功
# 1313 volume修改成功
# 1314 volume修改成功
# 1315 volume修改成功
# 1316 volume修改成功
# 1317 volume修改成功
# 1318 volume修改成功
# 1319 volume修改成功
# 1320 volume修改成功
# 1321 volume修改成功
# 1322 volume修改成功
# 1323 volume修改成功
# 1324 volume修改成功
# 1325 volume修改成功
# 1326 volume修改成功
# 1327 volume修改成功
# 1328 volume修改成功
# 1329 volume修改成功
# 1330 volume修改成功
# 1331 volume修改成功
# 1332 volume修改成功
# 1333 volume修改成功
# 1334 volume修改成功
# 1335 volume修改成功
# 1336 volume修改成功
# 1337 volume修改成功
# 1338 volume修改成功
# 1339 volume修改成功
# 1340 volume修改成功
# 1341 volume修改成功
# 1342 volume修改成功
# 1343 volume修改成功
# 1344 volume修改成功
# 1345 volume修改成功
# 1346 volume修改成功
# 1347 volume修改成功
# 1348 volume修改成功
# 1349 volume修改成功
# 1350 volume修改成功
# 1351 volume修改成功
# 1352 volume修改成功
# 1353 volume修改成功
# 1354 volume修改成功
# 1355 volume修改成功
# 1356 volume修改成功
# 1357 volume修改成功
# 1358 volume修改成功
# 1359 volume修改成功
# 1360 volume修改成功
# 1361 volume修改成功
# 1362 volume修改成功
# 1363 volume修改成功
# 1364 volume修改成功
# 1365 volume修改成功
# 1366 volume修改成功
# 1367 volume修改成功
# 1368 volume修改成功
# 1369 volume修改成功
# 1370 volume修改成功
# 1371 volume修改成功
# 1372 volume修改成功
# 1373 volume修改成功
# 1374 volume修改成功
# 1375 volume修改成功
# 1376 volume修改成功
# 1377 volume修改成功
# 1378 volume修改成功
# 1379 volume修改成功
# 1380 volume修改成功
# 1381 volume修改成功
# 1382 volume修改成功
# 1383 volume修改成功
# 1384 volume修改成功
# 1385 volume修改成功
# 1386 volume修改成功
# 1387 volume修改成功
# 1388 volume修改成功
# 1389 volume修改成功
# 1390 volume修改成功
# 1391 volume修改成功
# 1392 volume修改成功
# 1393 volume修改成功
# 1394 volume修改成功
# 1395 volume修改成功
# 1396 volume修改成功
# 1397 volume修改成功
# 1398 volume修改成功
# 1399 volume修改成功
# 1400 volume修改成功
# 1401 volume修改成功
# 1402 volume修改成功
# 1403 volume修改成功
# 1404 volume修改成功
# 1405 volume修改成功
# 1406 volume修改成功
# 1407 volume修改成功
# 1408 volume修改成功
# 1409 volume修改成功
# 1410 volume修改成功
# 1411 volume修改成功
# 1412 volume修改成功
# 1413 volume修改成功
# 1414 volume修改成功
# 1415 volume修改成功
# 1416 volume修改成功
# 1417 volume修改成功
# 1418 volume修改成功
# 1419 volume修改成功
# 1420 volume修改成功
# 1421 volume修改成功
# 1422 volume修改成功
# 1423 volume修改成功
# 1424 volume修改成功
# 1425 volume修改成功
# 1426 volume修改成功
# 1427 volume修改成功
# 1428 volume修改成功
# 1429 volume修改成功
# 1430 volume修改成功
# 1431 volume修改成功
# 1432 volume修改成功
# 1433 volume修改成功
# 1434 volume修改成功
# 1435 volume修改成功
# 1436 volume修改成功
# 1437 volume修改成功
# 1438 volume修改成功
# 2591 volume修改成功
# 2592 volume修改成功
# 2593 volume修改成功
# 2594 volume修改成功
# 2595 volume修改成功
# 2596 volume修改成功
# 2597 volume修改成功
# 2598 volume修改成功
# 2599 volume修改成功
# 2600 volume修改成功
# 2601 volume修改成功
# 2602 volume修改成功
# 2603 volume修改成功
# 2604 volume修改成功
# 2605 volume修改成功
# 2606 volume修改成功
# 2607 volume修改成功
# 2608 volume修改成功
# 2609 volume修改成功
# 2610 volume修改成功
# 2611 volume修改成功
# 2612 volume修改成功
# 2613 volume修改成功
# 2614 volume修改成功
# 2615 volume修改成功
# 2616 volume修改成功
# 2617 volume修改成功
# 2618 volume修改成功
# 2619 volume修改成功
# 2620 volume修改成功
# 2621 volume修改成功
# 2622 volume修改成功
# 2623 volume修改成功
# 2624 volume修改成功
# 2625 volume修改成功
# 2626 volume修改成功
# 2627 volume修改成功
# 2628 volume修改成功
# 2629 volume修改成功
# 2630 volume修改成功
# 2631 volume修改成功
# 2632 volume修改成功
# 2633 volume修改成功
# 2634 volume修改成功
# 2635 volume修改成功
# 2636 volume修改成功
# 2637 volume修改成功
# 2638 volume修改成功
# 2639 volume修改成功
# 2640 volume修改成功
# 2641 volume修改成功
# 2642 volume修改成功
# 2643 volume修改成功
# 2644 volume修改成功
# 2645 volume修改成功
# 2646 volume修改成功
# 2647 volume修改成功
# 2648 volume修改成功
# 2649 volume修改成功
# 2650 volume修改成功
# 2651 volume修改成功
# 2652 volume修改成功
# 2653 volume修改成功
# 2654 volume修改成功
# 2655 volume修改成功
# 2656 volume修改成功
# 2657 volume修改成功
# 2658 volume修改成功
# 2659 volume修改成功
# 2660 volume修改成功
# 2661 volume修改成功
# 2662 volume修改成功
# 2663 volume修改成功
# 2664 volume修改成功
# 2665 volume修改成功
# 2666 volume修改成功
# 2667 volume修改成功
# 2668 volume修改成功
# 2669 volume修改成功
# 2670 volume修改成功
# 2671 volume修改成功
# 2672 volume修改成功
# 2673 volume修改成功
# 2674 volume修改成功
# 2675 volume修改成功
# 2676 volume修改成功
# 2677 volume修改成功
# 2678 volume修改成功
# 2679 volume修改成功
# 2680 volume修改成功
# 2681 volume修改成功
# 2682 volume修改成功
# 2683 volume修改成功
# 2684 volume修改成功
# 2685 volume修改成功
# 2686 volume修改成功
# 2687 volume修改成功
# 2688 volume修改成功
# 2689 volume修改成功
# 2690 volume修改成功
# 2691 volume修改成功
# 2692 volume修改成功
# 2693 volume修改成功
# 2694 volume修改成功
# 2695 volume修改成功
# 2696 volume修改成功
# 2697 volume修改成功
# 2698 volume修改成功
# 2699 volume修改成功
# 2700 volume修改成功
# 2701 volume修改成功
# 2702 volume修改成功
# 2703 volume修改成功
# 2704 volume修改成功
# 2705 volume修改成功
# 2706 volume修改成功
# 2707 volume修改成功
# 2708 volume修改成功
# 2709 volume修改成功
# 2710 volume修改成功
# 2711 volume修改成功
# 2712 volume修改成功
# 2713 volume修改成功
# 2714 volume修改成功
# 2715 volume修改成功
# 2716 volume修改成功
# 2717 volume修改成功
# 2718 volume修改成功
# 2719 volume修改成功
# 2720 volume修改成功
# 2721 volume修改成功
# 2722 volume修改成功
# 2723 volume修改成功
# 2724 volume修改成功
# 2725 volume修改成功
# 2726 volume修改成功
# 2727 volume修改成功
# 2728 volume修改成功
# 2729 volume修改成功
# 2730 volume修改成功
# 2731 volume修改成功
# 2732 volume修改成功
# 2733 volume修改成功
# 2734 volume修改成功
# 2735 volume修改成功
# 2736 volume修改成功
# 2737 volume修改成功
# 2738 volume修改成功
# 2739 volume修改成功
# 2740 volume修改成功
# 2741 volume修改成功
# 2742 volume修改成功
# 2743 volume修改成功
# 2744 volume修改成功
# 2745 volume修改成功
# 2746 volume修改成功
# 2747 volume修改成功
# 2748 volume修改成功
# 2749 volume修改成功
# 2750 volume修改成功
# 2751 volume修改成功
# 2752 volume修改成功
# 2753 volume修改成功
# 2754 volume修改成功
# 2755 volume修改成功
# 2756 volume修改成功
# 2757 volume修改成功
# 2758 volume修改成功
# 2759 volume修改成功
# 2760 volume修改成功
# 2761 volume修改成功
# 2762 volume修改成功
# 2763 volume修改成功
# 2764 volume修改成功
# 2765 volume修改成功
# 2766 volume修改成功
# 2767 volume修改成功
# 2768 volume修改成功
# 2769 volume修改成功
# 2770 volume修改成功
# 2771 volume修改成功
# 2772 volume修改成功
# 2773 volume修改成功
# 2774 volume修改成功
# 2775 volume修改成功
# 2776 volume修改成功
# 2777 volume修改成功
# 2778 volume修改成功
# 2779 volume修改成功
# 2780 volume修改成功
# 2781 volume修改成功
# 2782 volume修改成功
# 2783 volume修改成功
# 2784 volume修改成功
# 2785 volume修改成功
# 2786 volume修改成功
# 2787 volume修改成功
# 2788 volume修改成功
# 2789 volume修改成功
# 2790 volume修改成功
# 2791 volume修改成功
# 2792 volume修改成功
# 2793 volume修改成功
# 2794 volume修改成功
# 2795 volume修改成功
# 2796 volume修改成功
# 2797 volume修改成功
# 2798 volume修改成功
# 2799 volume修改成功
# 2800 volume修改成功
# 2801 volume修改成功
# 2802 volume修改成功
# 2803 volume修改成功
# 2804 volume修改成功
# 2805 volume修改成功
# 2806 volume修改成功
# 2807 volume修改成功
# 2808 volume修改成功
# 2809 volume修改成功
# 2810 volume修改成功
# 2811 volume修改成功
# 2812 volume修改成功
# 2813 volume修改成功
# 2814 volume修改成功
# 2815 volume修改成功
# 2816 volume修改成功
# 2817 volume修改成功
# 2818 volume修改成功
# 2819 volume修改成功
# 2820 volume修改成功
# 2821 volume修改成功
# 2822 volume修改成功
# 2823 volume修改成功
# 2824 volume修改成功
# 2825 volume修改成功
# 2826 volume修改成功
# 2827 volume修改成功
# 2828 volume修改成功
# 2829 volume修改成功
# 2830 volume修改成功
# 2831 volume修改成功
# 2832 volume修改成功
# 2833 volume修改成功
# 2834 volume修改成功
# 2835 volume修改成功
# 2836 volume修改成功
# 2837 volume修改成功
# 2838 volume修改成功
# 2839 volume修改成功
# 2840 volume修改成功
# 2841 volume修改成功
# 2842 volume修改成功
# 2843 volume修改成功
# 2844 volume修改成功
# 2845 volume修改成功
# 2846 volume修改成功
# 2847 volume修改成功
# 2848 volume修改成功
# 2849 volume修改成功
# 2850 volume修改成功
# 2851 volume修改成功
# 2852 volume修改成功
# 2853 volume修改成功
# 2854 volume修改成功
# 2855 volume修改成功
# 2856 volume修改成功
# 2857 volume修改成功
# 2858 volume修改成功
# 2859 volume修改成功
# 2860 volume修改成功
# 2861 volume修改成功
# 2862 volume修改成功
# 2863 volume修改成功
# 2864 volume修改成功
# 2865 volume修改成功
# 2866 volume修改成功
# 2867 volume修改成功
# 2868 volume修改成功
# 2869 volume修改成功
# 2870 volume修改成功
# 2871 volume修改成功
# 2872 volume修改成功
# 2873 volume修改成功
# 2874 volume修改成功
# 2875 volume修改成功
# 2876 volume修改成功
# 2877 volume修改成功
# 2878 volume修改成功
# 2879 volume修改成功
# 2880 volume修改成功
# 2881 volume修改成功
# 2882 volume修改成功
# 2883 volume修改成功
# 2884 volume修改成功
# 2885 volume修改成功
# 2886 volume修改成功
# 2887 volume修改成功
# 2888 volume修改成功
# 2889 volume修改成功
# 2890 volume修改成功
# 2891 volume修改成功
# 2892 volume修改成功
# 2893 volume修改成功
# 2894 volume修改成功
# 2895 volume修改成功
# 2896 volume修改成功
# 2897 volume修改成功
# 2898 volume修改成功
# 2899 volume修改成功
# 2900 volume修改成功
# 2901 volume修改成功
# 2902 volume修改成功
# 2903 volume修改成功
# 2904 volume修改成功
# 2905 volume修改成功
# 2906 volume修改成功
# 2907 volume修改成功
# 2908 volume修改成功
# 2909 volume修改成功
# 2910 volume修改成功
# 2911 volume修改成功
# 2912 volume修改成功
# 2913 volume修改成功
# 2914 volume修改成功
# 2915 volume修改成功
# 2916 volume修改成功
# 2917 volume修改成功
# 2918 volume修改成功
# 2919 volume修改成功
# 2920 volume修改成功
# 2921 volume修改成功
# 2922 volume修改成功
# 2923 volume修改成功
# 2924 volume修改成功
# 2925 volume修改成功
# 2926 volume修改成功
# 2927 volume修改成功
# 2928 volume修改成功
# 2929 volume修改成功
# 2930 volume修改成功
# 2931 volume修改成功
# 2932 volume修改成功
# 2933 volume修改成功
# 2934 volume修改成功
# 2935 volume修改成功
# 2936 volume修改成功
# 2937 volume修改成功
# 2938 volume修改成功
# 2939 volume修改成功
# 2940 volume修改成功
# 2941 volume修改成功
# 2942 volume修改成功
# 2943 volume修改成功
# 2944 volume修改成功
# 2945 volume修改成功
# 2946 volume修改成功
# 2947 volume修改成功
# 2948 volume修改成功
# 2949 volume修改成功
# 2950 volume修改成功
# 2951 volume修改成功
# 2952 volume修改成功
# 2953 volume修改成功
# 2954 volume修改成功
# 2955 volume修改成功
# 2956 volume修改成功
# 2957 volume修改成功
# 2958 volume修改成功
# 2959 volume修改成功
# 2960 volume修改成功
# 2961 volume修改成功
# 2962 volume修改成功
# 2963 volume修改成功
# 2964 volume修改成功
# 2965 volume修改成功
# 2966 volume修改成功
# 2967 volume修改成功
# 2968 volume修改成功
# 2969 volume修改成功
# 2970 volume修改成功
# 2971 volume修改成功
# 2972 volume修改成功
# 2973 volume修改成功
# 2974 volume修改成功
# 2975 volume修改成功
# 2976 volume修改成功
# 2977 volume修改成功
# 2978 volume修改成功
# 2979 volume修改成功
# 2980 volume修改成功
# 2981 volume修改成功
# 2982 volume修改成功
# 2983 volume修改成功
# 2984 volume修改成功
# 2985 volume修改成功
# 2986 volume修改成功
# 2987 volume修改成功
# 2988 volume修改成功
# 2989 volume修改成功
# 2990 volume修改成功
# 2991 volume修改成功
# 2992 volume修改成功
# 2993 volume修改成功
# 2994 volume修改成功
# 2995 volume修改成功
# 2996 volume修改成功
# 2997 volume修改成功
# 2998 volume修改成功
# 2999 volume修改成功
# 3000 volume修改成功
# 3001 volume修改成功
# 3002 volume修改成功
# 3003 volume修改成功
# 3004 volume修改成功
# 3005 volume修改成功
# 3006 volume修改成功
# 3007 volume修改成功
# 3008 volume修改成功
# 3009 volume修改成功
# 3010 volume修改成功
# 3011 volume修改成功
# 3012 volume修改成功
# 3013 volume修改成功
# 3014 volume修改成功
# 3015 volume修改成功
# 3016 volume修改成功
# 3017 volume修改成功
# 3018 volume修改成功
# 3019 volume修改成功
# 3020 volume修改成功
# 3021 volume修改成功
# 3022 volume修改成功
# 3023 volume修改成功
# 3024 volume修改成功
# 3025 volume修改成功
# 3026 volume修改成功
# 3027 volume修改成功
# 3028 volume修改成功
# 3029 volume修改成功
# 3030 volume修改成功
# 3031 volume修改成功
# 3032 volume修改成功
# 3033 volume修改成功
# 3034 volume修改成功
# 3035 volume修改成功
# 3036 volume修改成功
# 3037 volume修改成功
# 3038 volume修改成功
# 3039 volume修改成功
# 3040 volume修改成功
# 3041 volume修改成功
# 3042 volume修改成功
# 3043 volume修改成功
# 3044 volume修改成功
# 3045 volume修改成功
# 3046 volume修改成功
# 3047 volume修改成功
# 3048 volume修改成功
# 3049 volume修改成功
# 3050 volume修改成功
# 3051 volume修改成功
# 3052 volume修改成功
# 3053 volume修改成功
# 3054 volume修改成功
# 3055 volume修改成功
# 3056 volume修改成功
# 3057 volume修改成功
# 3058 volume修改成功
# 3059 volume修改成功
# 3060 volume修改成功
# 3061 volume修改成功
# 3062 volume修改成功
# 3063 volume修改成功
# 3064 volume修改成功
# 3065 volume修改成功
# 3066 volume修改成功
# 3067 volume修改成功
# 3068 volume修改成功
# 3069 volume修改成功
# 3070 volume修改成功
# 3071 volume修改成功
# 3072 volume修改成功
# 3073 volume修改成功
# 3074 volume修改成功
# 3075 volume修改成功
# 3076 volume修改成功
# 3077 volume修改成功
# 3078 volume修改成功
# 3079 volume修改成功
# 3080 volume修改成功
# 3081 volume修改成功
# 3082 volume修改成功
# 3083 volume修改成功
# 3084 volume修改成功
# 3085 volume修改成功
# 3086 volume修改成功
# 3087 volume修改成功
# 3088 volume修改成功
# 3089 volume修改成功
# 3090 volume修改成功
# 3091 volume修改成功
# 3092 volume修改成功
# 3093 volume修改成功
# 3094 volume修改成功
# 3095 volume修改成功
# 3096 volume修改成功
# 3097 volume修改成功
# 3098 volume修改成功
# 3099 volume修改成功
# 3100 volume修改成功
# 3101 volume修改成功
# 3102 volume修改成功
# 3103 volume修改成功
# 3104 volume修改成功
# 3105 volume修改成功
# 3106 volume修改成功
# 3107 volume修改成功
# 3108 volume修改成功
# 3109 volume修改成功
# 3110 volume修改成功
# 3111 volume修改成功
# 3112 volume修改成功
# 3113 volume修改成功
# 3114 volume修改成功
# 3115 volume修改成功
# 3116 volume修改成功
# 3117 volume修改成功
# 3118 volume修改成功
# 3119 volume修改成功
# 3120 volume修改成功
# 3121 volume修改成功
# 3122 volume修改成功
# 3123 volume修改成功
# 3124 volume修改成功
# 3125 volume修改成功
# 3126 volume修改成功
# 3127 volume修改成功
# 3128 volume修改成功
# 3129 volume修改成功
# 3130 volume修改成功
# 3131 volume修改成功
# 3132 volume修改成功
# 3133 volume修改成功
# 3134 volume修改成功
# 3135 volume修改成功
# 3136 volume修改成功
# 3137 volume修改成功
# 3138 volume修改成功
# 3139 volume修改成功
# 3140 volume修改成功
# 3141 volume修改成功
# 3142 volume修改成功
# 3143 volume修改成功
# 3144 volume修改成功
# 3145 volume修改成功
# 3146 volume修改成功
# 3147 volume修改成功
# 3148 volume修改成功
# 3149 volume修改成功
# 3150 volume修改成功
# 3151 volume修改成功
# 3152 volume修改成功
# 3153 volume修改成功
# 3154 volume修改成功
# 3155 volume修改成功
# 3156 volume修改成功
# 3157 volume修改成功
# 3158 volume修改成功
# 3159 volume修改成功
# 3160 volume修改成功
# 3161 volume修改成功
# 3162 volume修改成功
# 3163 volume修改成功
# 3164 volume修改成功
# 3165 volume修改成功
# 3166 volume修改成功
# 6911 volume修改成功
# 6912 volume修改成功
# 6913 volume修改成功
# 6914 volume修改成功
# 6915 volume修改成功
# 6916 volume修改成功
# 6917 volume修改成功
# 6918 volume修改成功
# 6919 volume修改成功
# 6920 volume修改成功
# 6921 volume修改成功
# 6922 volume修改成功
# 6923 volume修改成功
# 6924 volume修改成功
# 6925 volume修改成功
# 6926 volume修改成功
# 6927 volume修改成功
# 6928 volume修改成功
# 6929 volume修改成功
# 6930 volume修改成功
# 6931 volume修改成功
# 6932 volume修改成功
# 6933 volume修改成功
# 6934 volume修改成功
# 6935 volume修改成功
# 6936 volume修改成功
# 6937 volume修改成功
# 6938 volume修改成功
# 6939 volume修改成功
# 6940 volume修改成功
# 6941 volume修改成功
# 6942 volume修改成功
# 6943 volume修改成功
# 6944 volume修改成功
# 6945 volume修改成功
# 6946 volume修改成功
# 6947 volume修改成功
# 6948 volume修改成功
# 6949 volume修改成功
# 6950 volume修改成功
# 6951 volume修改成功
# 6952 volume修改成功
# 6953 volume修改成功
# 6954 volume修改成功
# 6955 volume修改成功
# 6956 volume修改成功
# 6957 volume修改成功
# 6958 volume修改成功
# 6959 volume修改成功
# 6960 volume修改成功
# 6961 volume修改成功
# 6962 volume修改成功
# 6963 volume修改成功
# 6964 volume修改成功
# 6965 volume修改成功
# 6966 volume修改成功
# 6967 volume修改成功
# 6968 volume修改成功
# 6969 volume修改成功
# 6970 volume修改成功
# 6971 volume修改成功
# 6972 volume修改成功
# 6973 volume修改成功
# 6974 volume修改成功
# 6975 volume修改成功
# 6976 volume修改成功
# 6977 volume修改成功
# 6978 volume修改成功
# 6979 volume修改成功
# 6980 volume修改成功
# 6981 volume修改成功
# 6982 volume修改成功
# 6983 volume修改成功
# 6984 volume修改成功
# 6985 volume修改成功
# 6986 volume修改成功
# 6987 volume修改成功
# 6988 volume修改成功
# 6989 volume修改成功
# 6990 volume修改成功
# 6991 volume修改成功
# 6992 volume修改成功
# 6993 volume修改成功
# 6994 volume修改成功
# 6995 volume修改成功
# 6996 volume修改成功
# 6997 volume修改成功
# 6998 volume修改成功
# 6999 volume修改成功
# 7000 volume修改成功
# 7001 volume修改成功
# 7002 volume修改成功
# 7003 volume修改成功
# 7004 volume修改成功
# 7005 volume修改成功
# 7006 volume修改成功
# 7007 volume修改成功
# 7008 volume修改成功
# 7009 volume修改成功
# 7010 volume修改成功
# 7011 volume修改成功
# 7012 volume修改成功
# 7013 volume修改成功
# 7014 volume修改成功
# 7015 volume修改成功
# 7016 volume修改成功
# 7017 volume修改成功
# 7018 volume修改成功
# 7019 volume修改成功
# 7020 volume修改成功
# 7021 volume修改成功
# 7022 volume修改成功
# 7023 volume修改成功
# 7024 volume修改成功
# 7025 volume修改成功
# 7026 volume修改成功
# 7027 volume修改成功
# 7028 volume修改成功
# 7029 volume修改成功
# 7030 volume修改成功
# 7031 volume修改成功
# 7032 volume修改成功
# 7033 volume修改成功
# 7034 volume修改成功
# 7035 volume修改成功
# 7036 volume修改成功
# 7037 volume修改成功
# 7038 volume修改成功
# 7039 volume修改成功
# 7040 volume修改成功
# 7041 volume修改成功
# 7042 volume修改成功
# 7043 volume修改成功
# 7044 volume修改成功
# 7045 volume修改成功
# 7046 volume修改成功
# 7047 volume修改成功
# 7048 volume修改成功
# 7049 volume修改成功
# 7050 volume修改成功
# 7051 volume修改成功
# 7052 volume修改成功
# 7053 volume修改成功
# 7054 volume修改成功
# 7055 volume修改成功
# 7056 volume修改成功
# 7057 volume修改成功
# 7058 volume修改成功
# 7059 volume修改成功
# 7060 volume修改成功
# 7061 volume修改成功
# 7062 volume修改成功
# 7063 volume修改成功
# 7064 volume修改成功
# 7065 volume修改成功
# 7066 volume修改成功
# 7067 volume修改成功
# 7068 volume修改成功
# 7069 volume修改成功
# 7070 volume修改成功
# 7071 volume修改成功
# 7072 volume修改成功
# 7073 volume修改成功
# 7074 volume修改成功
# 7075 volume修改成功
# 7076 volume修改成功
# 7077 volume修改成功
# 7078 volume修改成功
# 7079 volume修改成功
# 7080 volume修改成功
# 7081 volume修改成功
# 7082 volume修改成功
# 7083 volume修改成功
# 7084 volume修改成功
# 7085 volume修改成功
# 7086 volume修改成功
# 7087 volume修改成功
# 7088 volume修改成功
# 7089 volume修改成功
# 7090 volume修改成功
# 7091 volume修改成功
# 7092 volume修改成功
# 7093 volume修改成功
# 7094 volume修改成功
# 7095 volume修改成功
# 7096 volume修改成功
# 7097 volume修改成功
# 7098 volume修改成功
# 7099 volume修改成功
# 7100 volume修改成功
# 7101 volume修改成功
# 7102 volume修改成功
# 7103 volume修改成功
# 7104 volume修改成功
# 7105 volume修改成功
# 7106 volume修改成功
# 7107 volume修改成功
# 7108 volume修改成功
# 7109 volume修改成功
# 7110 volume修改成功
# 7111 volume修改成功
# 7112 volume修改成功
# 7113 volume修改成功
# 7114 volume修改成功
# 7115 volume修改成功
# 7116 volume修改成功
# 7117 volume修改成功
# 7118 volume修改成功
# 7119 volume修改成功
# 7120 volume修改成功
# 7121 volume修改成功
# 7122 volume修改成功
# 7123 volume修改成功
# 7124 volume修改成功
# 7125 volume修改成功
# 7126 volume修改成功
# 7127 volume修改成功
# 7128 volume修改成功
# 7129 volume修改成功
# 7130 volume修改成功
# 7131 volume修改成功
# 7132 volume修改成功
# 7133 volume修改成功
# 7134 volume修改成功
# 7135 volume修改成功
# 7136 volume修改成功
# 7137 volume修改成功
# 7138 volume修改成功
# 7139 volume修改成功
# 7140 volume修改成功
# 7141 volume修改成功
# 7142 volume修改成功
# 7143 volume修改成功
# 7144 volume修改成功
# 7145 volume修改成功
# 7146 volume修改成功
# 7147 volume修改成功
# 7148 volume修改成功
# 7149 volume修改成功
# 7150 volume修改成功
# 7151 volume修改成功
# 7152 volume修改成功
# 7153 volume修改成功
# 7154 volume修改成功
# 7155 volume修改成功
# 7156 volume修改成功
# 7157 volume修改成功
# 7158 volume修改成功
# 7159 volume修改成功
# 7160 volume修改成功
# 7161 volume修改成功
# 7162 volume修改成功
# 7163 volume修改成功
# 7164 volume修改成功
# 7165 volume修改成功
# 7166 volume修改成功
# 7167 volume修改成功
# 7168 volume修改成功
# 7169 volume修改成功
# 7170 volume修改成功
# 7171 volume修改成功
# 7172 volume修改成功
# 7173 volume修改成功
# 7174 volume修改成功
# 7175 volume修改成功
# 7176 volume修改成功
# 7177 volume修改成功
# 7178 volume修改成功
# 7179 volume修改成功
# 7180 volume修改成功
# 7181 volume修改成功
# 7182 volume修改成功
# 7183 volume修改成功
# 7184 volume修改成功
# 7185 volume修改成功
# 7186 volume修改成功
# 7187 volume修改成功
# 7188 volume修改成功
# 7189 volume修改成功
# 7190 volume修改成功
# 7191 volume修改成功
# 7192 volume修改成功
# 7193 volume修改成功
# 7194 volume修改成功
# 7195 volume修改成功
# 7196 volume修改成功
# 7197 volume修改成功
# 7198 volume修改成功
# 7487 volume修改成功
# 7488 volume修改成功
# 7489 volume修改成功
# 7490 volume修改成功
# 7491 volume修改成功
# 7492 volume修改成功
# 7493 volume修改成功
# 7494 volume修改成功
# 7495 volume修改成功
# 7496 volume修改成功
# 7497 volume修改成功
# 7498 volume修改成功
# 7499 volume修改成功
# 7500 volume修改成功
# 7501 volume修改成功
# 7502 volume修改成功
# 7503 volume修改成功
# 7504 volume修改成功
# 7505 volume修改成功
# 7506 volume修改成功
# 7507 volume修改成功
# 7508 volume修改成功
# 7509 volume修改成功
# 7510 volume修改成功
# 7511 volume修改成功
# 7512 volume修改成功
# 7513 volume修改成功
# 7514 volume修改成功
# 7515 volume修改成功
# 7516 volume修改成功
# 7517 volume修改成功
# 7518 volume修改成功
# 7519 volume修改成功
# 7520 volume修改成功
# 7521 volume修改成功
# 7522 volume修改成功
# 7523 volume修改成功
# 7524 volume修改成功
# 7525 volume修改成功
# 7526 volume修改成功
# 7527 volume修改成功
# 7528 volume修改成功
# 7529 volume修改成功
# 7530 volume修改成功
# 7531 volume修改成功
# 7532 volume修改成功
# 7533 volume修改成功
# 7534 volume修改成功
# 7535 volume修改成功
# 7536 volume修改成功
# 7537 volume修改成功
# 7538 volume修改成功
# 7539 volume修改成功
# 7540 volume修改成功
# 7541 volume修改成功
# 7542 volume修改成功
# 7543 volume修改成功
# 7544 volume修改成功
# 7545 volume修改成功
# 7546 volume修改成功
# 7547 volume修改成功
# 7548 volume修改成功
# 7549 volume修改成功
# 7550 volume修改成功
# 7551 volume修改成功
# 7552 volume修改成功
# 7553 volume修改成功
# 7554 volume修改成功
# 7555 volume修改成功
# 7556 volume修改成功
# 7557 volume修改成功
# 7558 volume修改成功
# 7559 volume修改成功
# 7560 volume修改成功
# 7561 volume修改成功
# 7562 volume修改成功
# 7563 volume修改成功
# 7564 volume修改成功
# 7565 volume修改成功
# 7566 volume修改成功
# 7567 volume修改成功
# 7568 volume修改成功
# 7569 volume修改成功
# 7570 volume修改成功
# 7571 volume修改成功
# 7572 volume修改成功
# 7573 volume修改成功
# 7574 volume修改成功
# 7575 volume修改成功
# 7576 volume修改成功
# 7577 volume修改成功
# 7578 volume修改成功
# 7579 volume修改成功
# 7580 volume修改成功
# 7581 volume修改成功
# 7582 volume修改成功
# 7583 volume修改成功
# 7584 volume修改成功
# 7585 volume修改成功
# 7586 volume修改成功
# 7587 volume修改成功
# 7588 volume修改成功
# 7589 volume修改成功
# 7590 volume修改成功
# 7591 volume修改成功
# 7592 volume修改成功
# 7593 volume修改成功
# 7594 volume修改成功
# 7595 volume修改成功
# 7596 volume修改成功
# 7597 volume修改成功
# 7598 volume修改成功
# 7599 volume修改成功
# 7600 volume修改成功
# 7601 volume修改成功
# 7602 volume修改成功
# 7603 volume修改成功
# 7604 volume修改成功
# 7605 volume修改成功
# 7606 volume修改成功
# 7607 volume修改成功
# 7608 volume修改成功
# 7609 volume修改成功
# 7610 volume修改成功
# 7611 volume修改成功
# 7612 volume修改成功
# 7613 volume修改成功
# 7614 volume修改成功
# 7615 volume修改成功
# 7616 volume修改成功
# 7617 volume修改成功
# 7618 volume修改成功
# 7619 volume修改成功
# 7620 volume修改成功
# 7621 volume修改成功
# 7622 volume修改成功
# 7623 volume修改成功
# 7624 volume修改成功
# 7625 volume修改成功
# 7626 volume修改成功
# 7627 volume修改成功
# 7628 volume修改成功
# 7629 volume修改成功
# 7630 volume修改成功
# 7631 volume修改成功
# 7632 volume修改成功
# 7633 volume修改成功
# 7634 volume修改成功
# 7635 volume修改成功
# 7636 volume修改成功
# 7637 volume修改成功
# 7638 volume修改成功
# 7639 volume修改成功
# 7640 volume修改成功
# 7641 volume修改成功
# 7642 volume修改成功
# 7643 volume修改成功
# 7644 volume修改成功
# 7645 volume修改成功
# 7646 volume修改成功
# 7647 volume修改成功
# 7648 volume修改成功
# 7649 volume修改成功
# 7650 volume修改成功
# 7651 volume修改成功
# 7652 volume修改成功
# 7653 volume修改成功
# 7654 volume修改成功
# 7655 volume修改成功
# 7656 volume修改成功
# 7657 volume修改成功
# 7658 volume修改成功
# 7659 volume修改成功
# 7660 volume修改成功
# 7661 volume修改成功
# 7662 volume修改成功
# 7663 volume修改成功
# 7664 volume修改成功
# 7665 volume修改成功
# 7666 volume修改成功
# 7667 volume修改成功
# 7668 volume修改成功
# 7669 volume修改成功
# 7670 volume修改成功
# 7671 volume修改成功
# 7672 volume修改成功
# 7673 volume修改成功
# 7674 volume修改成功
# 7675 volume修改成功
# 7676 volume修改成功
# 7677 volume修改成功
# 7678 volume修改成功
# 7679 volume修改成功
# 7680 volume修改成功
# 7681 volume修改成功
# 7682 volume修改成功
# 7683 volume修改成功
# 7684 volume修改成功
# 7685 volume修改成功
# 7686 volume修改成功
# 7687 volume修改成功
# 7688 volume修改成功
# 7689 volume修改成功
# 7690 volume修改成功
# 7691 volume修改成功
# 7692 volume修改成功
# 7693 volume修改成功
# 7694 volume修改成功
# 7695 volume修改成功
# 7696 volume修改成功
# 7697 volume修改成功
# 7698 volume修改成功
# 7699 volume修改成功
# 7700 volume修改成功
# 7701 volume修改成功
# 7702 volume修改成功
# 7703 volume修改成功
# 7704 volume修改成功
# 7705 volume修改成功
# 7706 volume修改成功
# 7707 volume修改成功
# 7708 volume修改成功
# 7709 volume修改成功
# 7710 volume修改成功
# 7711 volume修改成功
# 7712 volume修改成功
# 7713 volume修改成功
# 7714 volume修改成功
# 7715 volume修改成功
# 7716 volume修改成功
# 7717 volume修改成功
# 7718 volume修改成功
# 7719 volume修改成功
# 7720 volume修改成功
# 7721 volume修改成功
# 7722 volume修改成功
# 7723 volume修改成功
# 7724 volume修改成功
# 7725 volume修改成功
# 7726 volume修改成功
# 7727 volume修改成功
# 7728 volume修改成功
# 7729 volume修改成功
# 7730 volume修改成功
# 7731 volume修改成功
# 7732 volume修改成功
# 7733 volume修改成功
# 7734 volume修改成功
# 7735 volume修改成功
# 7736 volume修改成功
# 7737 volume修改成功
# 7738 volume修改成功
# 7739 volume修改成功
# 7740 volume修改成功
# 7741 volume修改成功
# 7742 volume修改成功
# 7743 volume修改成功
# 7744 volume修改成功
# 7745 volume修改成功
# 7746 volume修改成功
# 7747 volume修改成功
# 7748 volume修改成功
# 7749 volume修改成功
# 7750 volume修改成功
# 7751 volume修改成功
# 7752 volume修改成功
# 7753 volume修改成功
# 7754 volume修改成功
# 7755 volume修改成功
# 7756 volume修改成功
# 7757 volume修改成功
# 7758 volume修改成功
# 7759 volume修改成功
# 7760 volume修改成功
# 7761 volume修改成功
# 7762 volume修改成功
# 7763 volume修改成功
# 7764 volume修改成功
# 7765 volume修改成功
# 7766 volume修改成功
# 7767 volume修改成功
# 7768 volume修改成功
# 7769 volume修改成功
# 7770 volume修改成功
# 7771 volume修改成功
# 7772 volume修改成功
# 7773 volume修改成功
# 7774 volume修改成功
# 7775 volume修改成功
# 7776 volume修改成功
# 7777 volume修改成功
# 7778 volume修改成功
# 7779 volume修改成功
# 7780 volume修改成功
# 7781 volume修改成功
# 7782 volume修改成功
# 7783 volume修改成功
# 7784 volume修改成功
# 7785 volume修改成功
# 7786 volume修改成功
# 7787 volume修改成功
# 7788 volume修改成功
# 7789 volume修改成功
# 7790 volume修改成功
# 7791 volume修改成功
# 7792 volume修改成功
# 7793 volume修改成功
# 7794 volume修改成功
# 7795 volume修改成功
# 7796 volume修改成功
# 7797 volume修改成功
# 7798 volume修改成功
# 7799 volume修改成功
# 7800 volume修改成功
# 7801 volume修改成功
# 7802 volume修改成功
# 7803 volume修改成功
# 7804 volume修改成功
# 7805 volume修改成功
# 7806 volume修改成功
# 7807 volume修改成功
# 7808 volume修改成功
# 7809 volume修改成功
# 7810 volume修改成功
# 7811 volume修改成功
# 7812 volume修改成功
# 7813 volume修改成功
# 7814 volume修改成功
# 7815 volume修改成功
# 7816 volume修改成功
# 7817 volume修改成功
# 7818 volume修改成功
# 7819 volume修改成功
# 7820 volume修改成功
# 7821 volume修改成功
# 7822 volume修改成功
# 7823 volume修改成功
# 7824 volume修改成功
# 7825 volume修改成功
# 7826 volume修改成功
# 7827 volume修改成功
# 7828 volume修改成功
# 7829 volume修改成功
# 7830 volume修改成功
# 7831 volume修改成功
# 7832 volume修改成功
# 7833 volume修改成功
# 7834 volume修改成功
# 7835 volume修改成功
# 7836 volume修改成功
# 7837 volume修改成功
# 7838 volume修改成功
# 7839 volume修改成功
# 7840 volume修改成功
# 7841 volume修改成功
# 7842 volume修改成功
# 7843 volume修改成功
# 7844 volume修改成功
# 7845 volume修改成功
# 7846 volume修改成功
# 7847 volume修改成功
# 7848 volume修改成功
# 7849 volume修改成功
# 7850 volume修改成功
# 7851 volume修改成功
# 7852 volume修改成功
# 7853 volume修改成功
# 7854 volume修改成功
# 7855 volume修改成功
# 7856 volume修改成功
# 7857 volume修改成功
# 7858 volume修改成功
# 7859 volume修改成功
# 7860 volume修改成功
# 7861 volume修改成功
# 7862 volume修改成功
# 7863 volume修改成功
# 7864 volume修改成功
# 7865 volume修改成功
# 7866 volume修改成功
# 7867 volume修改成功
# 7868 volume修改成功
# 7869 volume修改成功
# 7870 volume修改成功
# 7871 volume修改成功
# 7872 volume修改成功
# 7873 volume修改成功
# 7874 volume修改成功
# 7875 volume修改成功
# 7876 volume修改成功
# 7877 volume修改成功
# 7878 volume修改成功
# 7879 volume修改成功
# 7880 volume修改成功
# 7881 volume修改成功
# 7882 volume修改成功
# 7883 volume修改成功
# 7884 volume修改成功
# 7885 volume修改成功
# 7886 volume修改成功
# 7887 volume修改成功
# 7888 volume修改成功
# 7889 volume修改成功
# 7890 volume修改成功
# 7891 volume修改成功
# 7892 volume修改成功
# 7893 volume修改成功
# 7894 volume修改成功
# 7895 volume修改成功
# 7896 volume修改成功
# 7897 volume修改成功
# 7898 volume修改成功
# 7899 volume修改成功
# 7900 volume修改成功
# 7901 volume修改成功
# 7902 volume修改成功
# 7903 volume修改成功
# 7904 volume修改成功
# 7905 volume修改成功
# 7906 volume修改成功
# 7907 volume修改成功
# 7908 volume修改成功
# 7909 volume修改成功
# 7910 volume修改成功
# 7911 volume修改成功
# 7912 volume修改成功
# 7913 volume修改成功
# 7914 volume修改成功
# 7915 volume修改成功
# 7916 volume修改成功
# 7917 volume修改成功
# 7918 volume修改成功
# 7919 volume修改成功
# 7920 volume修改成功
# 7921 volume修改成功
# 7922 volume修改成功
# 7923 volume修改成功
# 7924 volume修改成功
# 7925 volume修改成功
# 7926 volume修改成功
# 7927 volume修改成功
# 7928 volume修改成功
# 7929 volume修改成功
# 7930 volume修改成功
# 7931 volume修改成功
# 7932 volume修改成功
# 7933 volume修改成功
# 7934 volume修改成功
# 7935 volume修改成功
# 7936 volume修改成功
# 7937 volume修改成功
# 7938 volume修改成功
# 7939 volume修改成功
# 7940 volume修改成功
# 7941 volume修改成功
# 7942 volume修改成功
# 7943 volume修改成功
# 7944 volume修改成功
# 7945 volume修改成功
# 7946 volume修改成功
# 7947 volume修改成功
# 7948 volume修改成功
# 7949 volume修改成功
# 7950 volume修改成功
# 7951 volume修改成功
# 7952 volume修改成功
# 7953 volume修改成功
# 7954 volume修改成功
# 7955 volume修改成功
# 7956 volume修改成功
# 7957 volume修改成功
# 7958 volume修改成功
# 7959 volume修改成功
# 7960 volume修改成功
# 7961 volume修改成功
# 7962 volume修改成功
# 7963 volume修改成功
# 7964 volume修改成功
# 7965 volume修改成功
# 7966 volume修改成功
# 7967 volume修改成功
# 7968 volume修改成功
# 7969 volume修改成功
# 7970 volume修改成功
# 7971 volume修改成功
# 7972 volume修改成功
# 7973 volume修改成功
# 7974 volume修改成功
# 7975 volume修改成功
# 7976 volume修改成功
# 7977 volume修改成功
# 7978 volume修改成功
# 7979 volume修改成功
# 7980 volume修改成功
# 7981 volume修改成功
# 7982 volume修改成功
# 7983 volume修改成功
# 7984 volume修改成功
# 7985 volume修改成功
# 7986 volume修改成功
# 7987 volume修改成功
# 7988 volume修改成功
# 7989 volume修改成功
# 7990 volume修改成功
# 7991 volume修改成功
# 7992 volume修改成功
# 7993 volume修改成功
# 7994 volume修改成功
# 7995 volume修改成功
# 7996 volume修改成功
# 7997 volume修改成功
# 7998 volume修改成功
# 7999 volume修改成功
# 8000 volume修改成功
# 8001 volume修改成功
# 8002 volume修改成功
# 8003 volume修改成功
# 8004 volume修改成功
# 8005 volume修改成功
# 8006 volume修改成功
# 8007 volume修改成功
# 8008 volume修改成功
# 8009 volume修改成功
# 8010 volume修改成功
# 8011 volume修改成功
# 8012 volume修改成功
# 8013 volume修改成功
# 8014 volume修改成功
# 8015 volume修改成功
# 8016 volume修改成功
# 8017 volume修改成功
# 8018 volume修改成功
# 8019 volume修改成功
# 8020 volume修改成功
# 8021 volume修改成功
# 8022 volume修改成功
# 8023 volume修改成功
# 8024 volume修改成功
# 8025 volume修改成功
# 8026 volume修改成功
# 8027 volume修改成功
# 8028 volume修改成功
# 8029 volume修改成功
# 8030 volume修改成功
# 8031 volume修改成功
# 8032 volume修改成功
# 8033 volume修改成功
# 8034 volume修改成功
# 8035 volume修改成功
# 8036 volume修改成功
# 8037 volume修改成功
# 8038 volume修改成功
# 8039 volume修改成功
# 8040 volume修改成功
# 8041 volume修改成功
# 8042 volume修改成功
# 8043 volume修改成功
# 8044 volume修改成功
# 8045 volume修改成功
# 8046 volume修改成功
# 8047 volume修改成功
# 8048 volume修改成功
# 8049 volume修改成功
# 8050 volume修改成功
# 8051 volume修改成功
# 8052 volume修改成功
# 8053 volume修改成功
# 8054 volume修改成功
# 8055 volume修改成功
# 8056 volume修改成功
# 8057 volume修改成功
# 8058 volume修改成功
# 8059 volume修改成功
# 8060 volume修改成功
# 8061 volume修改成功
# 8062 volume修改成功
# 8298 volume修改成功
# 8299 volume修改成功
# 8300 volume修改成功
# 8301 volume修改成功
# 8302 volume修改成功
# 8303 volume修改成功
# 8304 volume修改成功
# 8305 volume修改成功
# 8306 volume修改成功
# 8307 volume修改成功
# 8308 volume修改成功
# 8309 volume修改成功
# 8310 volume修改成功
# 8311 volume修改成功
# 8312 volume修改成功
# 8313 volume修改成功
# 8314 volume修改成功
# 8315 volume修改成功
# 8316 volume修改成功
# 8317 volume修改成功
# 8318 volume修改成功
# 8319 volume修改成功
# 8320 volume修改成功
# 8321 volume修改成功
# 8322 volume修改成功
# 8323 volume修改成功
# 8324 volume修改成功
# 8325 volume修改成功
# 8326 volume修改成功
# 8327 volume修改成功
# 8328 volume修改成功
# 8329 volume修改成功
# 8330 volume修改成功
# 8331 volume修改成功
# 8332 volume修改成功
# 8333 volume修改成功
# 8334 volume修改成功
# 8335 volume修改成功
# 8336 volume修改成功
# 8337 volume修改成功
# 8338 volume修改成功
# 8339 volume修改成功
# 8340 volume修改成功
# 8341 volume修改成功
# 8342 volume修改成功
# 8343 volume修改成功
# 8344 volume修改成功
# 8345 volume修改成功
# 8346 volume修改成功
# 8347 volume修改成功
# 8348 volume修改成功
# 8349 volume修改成功
# 8350 volume修改成功
# 8351 volume修改成功
# 8352 volume修改成功
# 8353 volume修改成功
# 8354 volume修改成功
# 8355 volume修改成功
# 8356 volume修改成功
# 8357 volume修改成功
# 8358 volume修改成功
# 8359 volume修改成功
# 8360 volume修改成功
# 8361 volume修改成功
# 8362 volume修改成功
# 8363 volume修改成功
# 8364 volume修改成功
# 8365 volume修改成功
# 8366 volume修改成功
# 8367 volume修改成功
# 8368 volume修改成功
# 8369 volume修改成功
# 8370 volume修改成功
# 8371 volume修改成功
# 8372 volume修改成功
# 8373 volume修改成功
# 8374 volume修改成功
# 8375 volume修改成功
# 8376 volume修改成功
# 8377 volume修改成功
# 8378 volume修改成功
# 8379 volume修改成功
# 8380 volume修改成功
# 8381 volume修改成功
# 8382 volume修改成功
# 8383 volume修改成功
# 8384 volume修改成功
# 8385 volume修改成功
# 8386 volume修改成功
# 8387 volume修改成功
# 8388 volume修改成功
# 8389 volume修改成功
# 8390 volume修改成功
# 8391 volume修改成功
# 8392 volume修改成功
# 8393 volume修改成功
# 8394 volume修改成功
# 8395 volume修改成功
# 8396 volume修改成功
# 8397 volume修改成功
# 8398 volume修改成功
# 8399 volume修改成功
# 8400 volume修改成功
# 8401 volume修改成功
# 8402 volume修改成功
# 8403 volume修改成功
# 8404 volume修改成功
# 8405 volume修改成功
# 8406 volume修改成功
# 8407 volume修改成功
# 8408 volume修改成功
# 8409 volume修改成功
# 8410 volume修改成功
# 8411 volume修改成功
# 8412 volume修改成功
# 8413 volume修改成功
# 8414 volume修改成功
# 8415 volume修改成功
# 8416 volume修改成功
# 8417 volume修改成功
# 8418 volume修改成功
# 8419 volume修改成功
# 8420 volume修改成功
# 8421 volume修改成功
# 8422 volume修改成功
# 8423 volume修改成功
# 8424 volume修改成功
# 8425 volume修改成功
# 8426 volume修改成功
# 8427 volume修改成功
# 8428 volume修改成功
# 8429 volume修改成功
# 8430 volume修改成功
# 8431 volume修改成功
# 8432 volume修改成功
# 8433 volume修改成功
# 8434 volume修改成功
# 8435 volume修改成功
# 8436 volume修改成功
# 8437 volume修改成功
# 8438 volume修改成功
# 8439 volume修改成功
# 8440 volume修改成功
# 8441 volume修改成功
# 8442 volume修改成功
# 8443 volume修改成功
# 8444 volume修改成功
# 8445 volume修改成功
# 8446 volume修改成功
# 8447 volume修改成功
# 8448 volume修改成功
# 8449 volume修改成功
# 8450 volume修改成功
# 8451 volume修改成功
# 8452 volume修改成功
# 8453 volume修改成功
# 8454 volume修改成功
# 8455 volume修改成功
# 8456 volume修改成功
# 8457 volume修改成功
# 8458 volume修改成功
# 8459 volume修改成功
# 8460 volume修改成功
# 8461 volume修改成功
# 8462 volume修改成功
# 8463 volume修改成功
# 8464 volume修改成功
# 8465 volume修改成功
# 8466 volume修改成功
# 8467 volume修改成功
# 8468 volume修改成功
# 8469 volume修改成功
# 8470 volume修改成功
# 8471 volume修改成功
# 8472 volume修改成功
# 8473 volume修改成功
# 8474 volume修改成功
# 8475 volume修改成功
# 8476 volume修改成功
# 8477 volume修改成功
# 8478 volume修改成功
# 8479 volume修改成功
# 8480 volume修改成功
# 8481 volume修改成功
# 8482 volume修改成功
# 8483 volume修改成功
# 8484 volume修改成功
# 8485 volume修改成功
# 8486 volume修改成功
# 8487 volume修改成功
# 8488 volume修改成功
# 8489 volume修改成功
# 8490 volume修改成功
# 8491 volume修改成功
# 8492 volume修改成功
# 8493 volume修改成功
# 8494 volume修改成功
# 8495 volume修改成功
# 8496 volume修改成功
# 8497 volume修改成功
# 8498 volume修改成功
# 8499 volume修改成功
# 8500 volume修改成功
# 8501 volume修改成功
# 8502 volume修改成功
# 8503 volume修改成功
# 8504 volume修改成功
# 8505 volume修改成功
# 8506 volume修改成功
# 8507 volume修改成功
# 8508 volume修改成功
# 8509 volume修改成功
# 8510 volume修改成功
# 8511 volume修改成功
# 8512 volume修改成功
# 8513 volume修改成功
# 8514 volume修改成功
# 8515 volume修改成功
# 8516 volume修改成功
# ...
# 7569 occupancy修改成功
# 7570 occupancy修改成功
# 7571 occupancy修改成功
# 7572 occupancy修改成功
# 7573 occupancy修改成功
# 7574 occupancy修改成功
# 7575 occupancy修改成功
# 7576 occupancy修改成功
# 7577 occupancy修改成功
# 7578 occupancy修改成功
# 7579 occupancy修改成功
# 7580 occupancy修改成功
# 7581 occupancy修改成功
# 7582 occupancy修改成功
# 7583 occupancy修改成功
# 7584 occupancy修改成功
# 7585 occupancy修改成功
# 7586 occupancy修改成功
# 7587 occupancy修改成功
# 7588 occupancy修改成功
# 7589 occupancy修改成功
# 7590 occupancy修改成功
# 7591 occupancy修改成功
# 7592 occupancy修改成功
# 7593 occupancy修改成功
# 7594 occupancy修改成功
# 7595 occupancy修改成功
# 7596 occupancy修改成功
# 7597 occupancy修改成功
# 7598 occupancy修改成功
# 7599 occupancy修改成功
# 7600 occupancy修改成功
# 7601 occupancy修改成功
# 7602 occupancy修改成功
# 7603 occupancy修改成功
# 7604 occupancy修改成功
# 7605 occupancy修改成功
# 7606 occupancy修改成功
# 7607 occupancy修改成功
# 7608 occupancy修改成功
# 7609 occupancy修改成功
# 7610 occupancy修改成功
# 7611 occupancy修改成功
# 7612 occupancy修改成功
# 7613 occupancy修改成功
# 7614 occupancy修改成功
# 7615 occupancy修改成功
# 7616 occupancy修改成功
# 7617 occupancy修改成功
# 7618 occupancy修改成功
# 7619 occupancy修改成功
# 7620 occupancy修改成功
# 7621 occupancy修改成功
# 7622 occupancy修改成功
# 7623 occupancy修改成功
# 7624 occupancy修改成功
# 7625 occupancy修改成功
# 7626 occupancy修改成功
# 7627 occupancy修改成功
# 7628 occupancy修改成功
# 7629 occupancy修改成功
# 7630 occupancy修改成功
# 7631 occupancy修改成功
# 7632 occupancy修改成功
# 7633 occupancy修改成功
# 7634 occupancy修改成功
# 7635 occupancy修改成功
# 7636 occupancy修改成功
# 7637 occupancy修改成功
# 7638 occupancy修改成功
# 7639 occupancy修改成功
# 7640 occupancy修改成功
# 7641 occupancy修改成功
# 7642 occupancy修改成功
# 7643 occupancy修改成功
# 7644 occupancy修改成功
# 7645 occupancy修改成功
# 7646 occupancy修改成功
# 7647 occupancy修改成功
# 7648 occupancy修改成功
# 7649 occupancy修改成功
# 7650 occupancy修改成功
# 7651 occupancy修改成功
# 7652 occupancy修改成功
# 7653 occupancy修改成功
# 7654 occupancy修改成功
# 7655 occupancy修改成功
# 7656 occupancy修改成功
# 7657 occupancy修改成功
# 7658 occupancy修改成功
# 7659 occupancy修改成功
# 7660 occupancy修改成功
# 7661 occupancy修改成功
# 7662 occupancy修改成功
# 7663 occupancy修改成功
# 7664 occupancy修改成功
# 7665 occupancy修改成功
# 7666 occupancy修改成功
# 7667 occupancy修改成功
# 7668 occupancy修改成功
# 7669 occupancy修改成功
# 7670 occupancy修改成功
# 7671 occupancy修改成功
# 7672 occupancy修改成功
# 7673 occupancy修改成功
# 7674 occupancy修改成功
# 7675 occupancy修改成功
# 7676 occupancy修改成功
# 7677 occupancy修改成功
# 7678 occupancy修改成功
# 7679 occupancy修改成功
# 7680 occupancy修改成功
# 7681 occupancy修改成功
# 7682 occupancy修改成功
# 7683 occupancy修改成功
# 7684 occupancy修改成功
# 7685 occupancy修改成功
# 7686 occupancy修改成功
# 7687 occupancy修改成功
# 7688 occupancy修改成功
# 7689 occupancy修改成功
# 7690 occupancy修改成功
# 7691 occupancy修改成功
# 7692 occupancy修改成功
# 7693 occupancy修改成功
# 7694 occupancy修改成功
# 7695 occupancy修改成功
# 7696 occupancy修改成功
# 7697 occupancy修改成功
# 7698 occupancy修改成功
# 7699 occupancy修改成功
# 7700 occupancy修改成功
# 7701 occupancy修改成功
# 7702 occupancy修改成功
# 7703 occupancy修改成功
# 7704 occupancy修改成功
# 7705 occupancy修改成功
# 7706 occupancy修改成功
# 7707 occupancy修改成功
# 7708 occupancy修改成功
# 7709 occupancy修改成功
# 7710 occupancy修改成功
# 7711 occupancy修改成功
# 7712 occupancy修改成功
# 7713 occupancy修改成功
# 7714 occupancy修改成功
# 7715 occupancy修改成功
# 7716 occupancy修改成功
# 7717 occupancy修改成功
# 7718 occupancy修改成功
# 7719 occupancy修改成功
# 7720 occupancy修改成功
# 7721 occupancy修改成功
# 7722 occupancy修改成功
# 7723 occupancy修改成功
# 7724 occupancy修改成功
# 7725 occupancy修改成功
# 7726 occupancy修改成功
# 7727 occupancy修改成功
# 7728 occupancy修改成功
# 7729 occupancy修改成功
# 7730 occupancy修改成功
# 7731 occupancy修改成功
# 7732 occupancy修改成功
# 7733 occupancy修改成功
# 7734 occupancy修改成功
# 7735 occupancy修改成功
# 7736 occupancy修改成功
# 7737 occupancy修改成功
# 7738 occupancy修改成功
# 7739 occupancy修改成功
# 7740 occupancy修改成功
# 7741 occupancy修改成功
# 7742 occupancy修改成功
# 7743 occupancy修改成功
# 7744 occupancy修改成功
# 7745 occupancy修改成功
# 7746 occupancy修改成功
# 7747 occupancy修改成功
# 7748 occupancy修改成功
# 7749 occupancy修改成功
# 7750 occupancy修改成功
# 7751 occupancy修改成功
# 7752 occupancy修改成功
# 7753 occupancy修改成功
# 7754 occupancy修改成功
# 7755 occupancy修改成功
# 7756 occupancy修改成功
# 7757 occupancy修改成功
# 7758 occupancy修改成功
# 7759 occupancy修改成功
# 7760 occupancy修改成功
# 7761 occupancy修改成功
# 7762 occupancy修改成功
# 7763 occupancy修改成功
# 7764 occupancy修改成功
# 7765 occupancy修改成功
# 7766 occupancy修改成功
# 7767 occupancy修改成功
# 7768 occupancy修改成功
# 7769 occupancy修改成功
# 7770 occupancy修改成功
# 7771 occupancy修改成功
# 7772 occupancy修改成功
# 7773 occupancy修改成功
# 7774 occupancy修改成功
# 7775 occupancy修改成功
# 7776 occupancy修改成功
# 7777 occupancy修改成功
# 7778 occupancy修改成功
# 7779 occupancy修改成功
# 7780 occupancy修改成功
# 7781 occupancy修改成功
# 7782 occupancy修改成功
# 7783 occupancy修改成功
# 7784 occupancy修改成功
# 7785 occupancy修改成功
# 7786 occupancy修改成功
# 7787 occupancy修改成功
# 7788 occupancy修改成功
# 7789 occupancy修改成功
# 7790 occupancy修改成功
# 7791 occupancy修改成功
# 7792 occupancy修改成功
# 7793 occupancy修改成功
# 7794 occupancy修改成功
# 7795 occupancy修改成功
# 7796 occupancy修改成功
# 7797 occupancy修改成功
# 7798 occupancy修改成功
# 7799 occupancy修改成功
# 7800 occupancy修改成功
# 7801 occupancy修改成功
# 7802 occupancy修改成功
# 7803 occupancy修改成功
# 7804 occupancy修改成功
# 7805 occupancy修改成功
# 7806 occupancy修改成功
# 7807 occupancy修改成功
# 7808 occupancy修改成功
# 7809 occupancy修改成功
# 7810 occupancy修改成功
# 7811 occupancy修改成功
# 7812 occupancy修改成功
# 7813 occupancy修改成功
# 7814 occupancy修改成功
# 7815 occupancy修改成功
# 7816 occupancy修改成功
# 7817 occupancy修改成功
# 7818 occupancy修改成功
# 7819 occupancy修改成功
# 7820 occupancy修改成功
# 7821 occupancy修改成功
# 7822 occupancy修改成功
# 7823 occupancy修改成功
# 7824 occupancy修改成功
# 7825 occupancy修改成功
# 7826 occupancy修改成功
# 7827 occupancy修改成功
# 7828 occupancy修改成功
# 7829 occupancy修改成功
# 7830 occupancy修改成功
# 7831 occupancy修改成功
# 7832 occupancy修改成功
# 7833 occupancy修改成功
# 7834 occupancy修改成功
# 7835 occupancy修改成功
# 7836 occupancy修改成功
# 7837 occupancy修改成功
# 7838 occupancy修改成功
# 7839 occupancy修改成功
# 7840 occupancy修改成功
# 7841 occupancy修改成功
# 7842 occupancy修改成功
# 7843 occupancy修改成功
# 7844 occupancy修改成功
# 7845 occupancy修改成功
# 7846 occupancy修改成功
# 7847 occupancy修改成功
# 7848 occupancy修改成功
# 7849 occupancy修改成功
# 7850 occupancy修改成功
# 7851 occupancy修改成功
# 7852 occupancy修改成功
# 7853 occupancy修改成功
# 7854 occupancy修改成功
# 7855 occupancy修改成功
# 7856 occupancy修改成功
# 7857 occupancy修改成功
# 7858 occupancy修改成功
# 7859 occupancy修改成功
# 7860 occupancy修改成功
# 7861 occupancy修改成功
# 7862 occupancy修改成功
# 7863 occupancy修改成功
# 7864 occupancy修改成功
# 7865 occupancy修改成功
# 7866 occupancy修改成功
# 7867 occupancy修改成功
# 7868 occupancy修改成功
# 7869 occupancy修改成功
# 7870 occupancy修改成功
# 7871 occupancy修改成功
# 7872 occupancy修改成功
# 7873 occupancy修改成功
# 7874 occupancy修改成功
# 7875 occupancy修改成功
# 7876 occupancy修改成功
# 7877 occupancy修改成功
# 7878 occupancy修改成功
# 7879 occupancy修改成功
# 7880 occupancy修改成功
# 7881 occupancy修改成功
# 7882 occupancy修改成功
# 7883 occupancy修改成功
# 7884 occupancy修改成功
# 7885 occupancy修改成功
# 7886 occupancy修改成功
# 7887 occupancy修改成功
# 7888 occupancy修改成功
# 7889 occupancy修改成功
# 7890 occupancy修改成功
# 7891 occupancy修改成功
# 7892 occupancy修改成功
# 7893 occupancy修改成功
# 7894 occupancy修改成功
# 7895 occupancy修改成功
# 7896 occupancy修改成功
# 7897 occupancy修改成功
# 7898 occupancy修改成功
# 7899 occupancy修改成功
# 7900 occupancy修改成功
# 7901 occupancy修改成功
# 7902 occupancy修改成功
# 7903 occupancy修改成功
# 7904 occupancy修改成功
# 7905 occupancy修改成功
# 7906 occupancy修改成功
# 7907 occupancy修改成功
# 7908 occupancy修改成功
# 7909 occupancy修改成功
# 7910 occupancy修改成功
# 7911 occupancy修改成功
# 7912 occupancy修改成功
# 7913 occupancy修改成功
# 7914 occupancy修改成功
# 7915 occupancy修改成功
# 7916 occupancy修改成功
# 7917 occupancy修改成功
# 7918 occupancy修改成功
# 7919 occupancy修改成功
# 7920 occupancy修改成功
# 7921 occupancy修改成功
# 7922 occupancy修改成功
# 7923 occupancy修改成功
# 7924 occupancy修改成功
# 7925 occupancy修改成功
# 7926 occupancy修改成功
# 7927 occupancy修改成功
# 7928 occupancy修改成功
# 7929 occupancy修改成功
# 7930 occupancy修改成功
# 7931 occupancy修改成功
# 7932 occupancy修改成功
# 7933 occupancy修改成功
# 7934 occupancy修改成功
# 7935 occupancy修改成功
# 7936 occupancy修改成功
# 7937 occupancy修改成功
# 7938 occupancy修改成功
# 7939 occupancy修改成功
# 7940 occupancy修改成功
# 7941 occupancy修改成功
# 7942 occupancy修改成功
# 7943 occupancy修改成功
# 7944 occupancy修改成功
# 7945 occupancy修改成功
# 7946 occupancy修改成功
# 7947 occupancy修改成功
# 7948 occupancy修改成功
# 7949 occupancy修改成功
# 7950 occupancy修改成功
# 7951 occupancy修改成功
# 7952 occupancy修改成功
# 7953 occupancy修改成功
# 7954 occupancy修改成功
# 7955 occupancy修改成功
# 7956 occupancy修改成功
# 7957 occupancy修改成功
# 7958 occupancy修改成功
# 7959 occupancy修改成功
# 7960 occupancy修改成功
# 7961 occupancy修改成功
# 7962 occupancy修改成功
# 7963 occupancy修改成功
# 7964 occupancy修改成功
# 7965 occupancy修改成功
# 7966 occupancy修改成功
# 7967 occupancy修改成功
# 7968 occupancy修改成功
# 7969 occupancy修改成功
# 7970 occupancy修改成功
# 7971 occupancy修改成功
# 7972 occupancy修改成功
# 7973 occupancy修改成功
# 7974 occupancy修改成功
# 7975 occupancy修改成功
# 7976 occupancy修改成功
# 7977 occupancy修改成功
# 7978 occupancy修改成功
# 7979 occupancy修改成功
# 7980 occupancy修改成功
# 7981 occupancy修改成功
# 7982 occupancy修改成功
# 7983 occupancy修改成功
# 7984 occupancy修改成功
# 7985 occupancy修改成功
# 7986 occupancy修改成功
# 7987 occupancy修改成功
# 7988 occupancy修改成功
# 7989 occupancy修改成功
# 7990 occupancy修改成功
# 7991 occupancy修改成功
# 7992 occupancy修改成功
# 7993 occupancy修改成功
# 7994 occupancy修改成功
# 7995 occupancy修改成功
# 7996 occupancy修改成功
# 7997 occupancy修改成功
# 7998 occupancy修改成功
# 7999 occupancy修改成功
# 8000 occupancy修改成功
# 8001 occupancy修改成功
# 8002 occupancy修改成功
# 8003 occupancy修改成功
# 8004 occupancy修改成功
# 8005 occupancy修改成功
# 8006 occupancy修改成功
# 8007 occupancy修改成功
# 8008 occupancy修改成功
# 8009 occupancy修改成功
# 8010 occupancy修改成功
# 8011 occupancy修改成功
# 8012 occupancy修改成功
# 8013 occupancy修改成功
# 8014 occupancy修改成功
# 8015 occupancy修改成功
# 8016 occupancy修改成功
# 8017 occupancy修改成功
# 8018 occupancy修改成功
# 8019 occupancy修改成功
# 8020 occupancy修改成功
# 8021 occupancy修改成功
# 8022 occupancy修改成功
# 8023 occupancy修改成功
# 8024 occupancy修改成功
# 8025 occupancy修改成功
# 8026 occupancy修改成功
# 8027 occupancy修改成功
# 8028 occupancy修改成功
# 8029 occupancy修改成功
# 8030 occupancy修改成功
# 8031 occupancy修改成功
# 8032 occupancy修改成功
# 8033 occupancy修改成功
# 8034 occupancy修改成功
# 8035 occupancy修改成功
# 8036 occupancy修改成功
# 8037 occupancy修改成功
# 8038 occupancy修改成功
# 8039 occupancy修改成功
# 8040 occupancy修改成功
# 8041 occupancy修改成功
# 8042 occupancy修改成功
# 8043 occupancy修改成功
# 8044 occupancy修改成功
# 8045 occupancy修改成功
# 8046 occupancy修改成功
# 8047 occupancy修改成功
# 8048 occupancy修改成功
# 8049 occupancy修改成功
# 8050 occupancy修改成功
# 8051 occupancy修改成功
# 8052 occupancy修改成功
# 8053 occupancy修改成功
# 8054 occupancy修改成功
# 8055 occupancy修改成功
# 8056 occupancy修改成功
# 8057 occupancy修改成功
# 8058 occupancy修改成功
# 8059 occupancy修改成功
# 8060 occupancy修改成功
# 8061 occupancy修改成功
# 8062 occupancy修改成功
# 8298 occupancy修改成功
# 8299 occupancy修改成功
# 8300 occupancy修改成功
# 8301 occupancy修改成功
# 8302 occupancy修改成功
# 8303 occupancy修改成功
# 8304 occupancy修改成功
# 8305 occupancy修改成功
# 8306 occupancy修改成功
# 8307 occupancy修改成功
# 8308 occupancy修改成功
# 8309 occupancy修改成功
# 8310 occupancy修改成功
# 8311 occupancy修改成功
# 8312 occupancy修改成功
# 8313 occupancy修改成功
# 8314 occupancy修改成功
# 8315 occupancy修改成功
# 8316 occupancy修改成功
# 8317 occupancy修改成功
# 8318 occupancy修改成功
# 8319 occupancy修改成功
# 8320 occupancy修改成功
# 8321 occupancy修改成功
# 8322 occupancy修改成功
# 8323 occupancy修改成功
# 8324 occupancy修改成功
# 8325 occupancy修改成功
# 8326 occupancy修改成功
# 8327 occupancy修改成功
# 8328 occupancy修改成功
# 8329 occupancy修改成功
# 8330 occupancy修改成功
# 8331 occupancy修改成功
# 8332 occupancy修改成功
# 8333 occupancy修改成功
# 8334 occupancy修改成功
# 8335 occupancy修改成功
# 8336 occupancy修改成功
# 8337 occupancy修改成功
# 8338 occupancy修改成功
# 8339 occupancy修改成功
# 8340 occupancy修改成功
# 8341 occupancy修改成功
# 8342 occupancy修改成功
# 8343 occupancy修改成功
# 8344 occupancy修改成功
# 8345 occupancy修改成功
# 8346 occupancy修改成功
# 8347 occupancy修改成功
# 8348 occupancy修改成功
# 8349 occupancy修改成功
# 8350 occupancy修改成功
# 8351 occupancy修改成功
# 8352 occupancy修改成功
# 8353 occupancy修改成功
# 8354 occupancy修改成功
# 8355 occupancy修改成功
# 8356 occupancy修改成功
# 8357 occupancy修改成功
# 8358 occupancy修改成功
# 8359 occupancy修改成功
# 8360 occupancy修改成功
# 8361 occupancy修改成功
# 8362 occupancy修改成功
# 8363 occupancy修改成功
# 8364 occupancy修改成功
# 8365 occupancy修改成功
# 8366 occupancy修改成功
# 8367 occupancy修改成功
# 8368 occupancy修改成功
# 8369 occupancy修改成功
# 8370 occupancy修改成功
# 8371 occupancy修改成功
# 8372 occupancy修改成功
# 8373 occupancy修改成功
# 8374 occupancy修改成功
# 8375 occupancy修改成功
# 8376 occupancy修改成功
# 8377 occupancy修改成功
# 8378 occupancy修改成功
# 8379 occupancy修改成功
# 8380 occupancy修改成功
# 8381 occupancy修改成功
# 8382 occupancy修改成功
# 8383 occupancy修改成功
# 8384 occupancy修改成功
# 8385 occupancy修改成功
# 8386 occupancy修改成功
# 8387 occupancy修改成功
# 8388 occupancy修改成功
# 8389 occupancy修改成功
# 8390 occupancy修改成功
# 8391 occupancy修改成功
# 8392 occupancy修改成功
# 8393 occupancy修改成功
# 8394 occupancy修改成功
# 8395 occupancy修改成功
# 8396 occupancy修改成功
# 8397 occupancy修改成功
# 8398 occupancy修改成功
# 8399 occupancy修改成功
# 8400 occupancy修改成功
# 8401 occupancy修改成功
# 8402 occupancy修改成功
# 8403 occupancy修改成功
# 8404 occupancy修改成功
# 8405 occupancy修改成功
# 8406 occupancy修改成功
# 8407 occupancy修改成功
# 8408 occupancy修改成功
# 8409 occupancy修改成功
# 8410 occupancy修改成功
# 8411 occupancy修改成功
# 8412 occupancy修改成功
# 8413 occupancy修改成功
# 8414 occupancy修改成功
# 8415 occupancy修改成功
# 8416 occupancy修改成功
# 8417 occupancy修改成功
# 8418 occupancy修改成功
# 8419 occupancy修改成功
# 8420 occupancy修改成功
# 8421 occupancy修改成功
# 8422 occupancy修改成功
# 8423 occupancy修改成功
# 8424 occupancy修改成功
# 8425 occupancy修改成功
# 8426 occupancy修改成功
# 8427 occupancy修改成功
# 8428 occupancy修改成功
# 8429 occupancy修改成功
# 8430 occupancy修改成功
# 8431 occupancy修改成功
# 8432 occupancy修改成功
# 8433 occupancy修改成功
# 8434 occupancy修改成功
# 8435 occupancy修改成功
# 8436 occupancy修改成功
# 8437 occupancy修改成功
# 8438 occupancy修改成功
# 8439 occupancy修改成功
# 8440 occupancy修改成功
# 8441 occupancy修改成功
# 8442 occupancy修改成功
# 8443 occupancy修改成功
# 8444 occupancy修改成功
# 8445 occupancy修改成功
# 8446 occupancy修改成功
# 8447 occupancy修改成功
# 8448 occupancy修改成功
# 8449 occupancy修改成功
# 8450 occupancy修改成功
# 8451 occupancy修改成功
# 8452 occupancy修改成功
# 8453 occupancy修改成功
# 8454 occupancy修改成功
# 8455 occupancy修改成功
# 8456 occupancy修改成功
# 8457 occupancy修改成功
# 8458 occupancy修改成功
# 8459 occupancy修改成功
# 8460 occupancy修改成功
# 8461 occupancy修改成功
# 8462 occupancy修改成功
# 8463 occupancy修改成功
# 8464 occupancy修改成功
# 8465 occupancy修改成功
# 8466 occupancy修改成功
# 8467 occupancy修改成功
# 8468 occupancy修改成功
# 8469 occupancy修改成功
# 8470 occupancy修改成功
# 8471 occupancy修改成功
# 8472 occupancy修改成功
# 8473 occupancy修改成功
# 8474 occupancy修改成功
# 8475 occupancy修改成功
# 8476 occupancy修改成功
# 8477 occupancy修改成功
# 8478 occupancy修改成功
# 8479 occupancy修改成功
# 8480 occupancy修改成功
# 8481 occupancy修改成功
# 8482 occupancy修改成功
# 8483 occupancy修改成功
# 8484 occupancy修改成功
# 8485 occupancy修改成功
# 8486 occupancy修改成功
# 8487 occupancy修改成功
# 8488 occupancy修改成功
# 8489 occupancy修改成功
# 8490 occupancy修改成功
# 8491 occupancy修改成功
# 8492 occupancy修改成功
# 8493 occupancy修改成功
# 8494 occupancy修改成功
# 8495 occupancy修改成功
# 8496 occupancy修改成功
# 8497 occupancy修改成功
# 8498 occupancy修改成功
# 8499 occupancy修改成功
# 8500 occupancy修改成功
# 8501 occupancy修改成功
# 8502 occupancy修改成功
# 8503 occupancy修改成功
# 8504 occupancy修改成功
# 8505 occupancy修改成功
# 8506 occupancy修改成功
# 8507 occupancy修改成功
# 8508 occupancy修改成功
# 8509 occupancy修改成功
# 8510 occupancy修改成功
# 8511 occupancy修改成功
# 8512 occupancy修改成功
# 8513 occupancy修改成功
# 8514 occupancy修改成功
# 8515 occupancy修改成功
# 8516 occupancy修改成功
# 8517 occupancy修改成功
# 8518 occupancy修改成功
# 8519 occupancy修改成功
# 8520 occupancy修改成功
# 8521 occupancy修改成功
# 8522 occupancy修改成功
# 8523 occupancy修改成功
# 8524 occupancy修改成功
# 8525 occupancy修改成功
# 8526 occupancy修改成功
# 8527 occupancy修改成功
# 8528 occupancy修改成功
# 8529 occupancy修改成功
# 8530 occupancy修改成功
# 8531 occupancy修改成功
# 8532 occupancy修改成功
# 8533 occupancy修改成功
# 8534 occupancy修改成功
# 8535 occupancy修改成功
# 8536 occupancy修改成功
# 8537 occupancy修改成功
# 8538 occupancy修改成功
# 8539 occupancy修改成功
# 8540 occupancy修改成功
# 8541 occupancy修改成功
# 8542 occupancy修改成功
# 8543 occupancy修改成功
# 8544 occupancy修改成功
# 8545 occupancy修改成功
# 8546 occupancy修改成功
# 8547 occupancy修改成功
# 8548 occupancy修改成功
# 8549 occupancy修改成功
# 8550 occupancy修改成功
# 8551 occupancy修改成功
# 8552 occupancy修改成功
# 8553 occupancy修改成功
# 8554 occupancy修改成功
# 8555 occupancy修改成功
# 8556 occupancy修改成功
# 8557 occupancy修改成功
# 8558 occupancy修改成功
# 8559 occupancy修改成功
# 8560 occupancy修改成功
# 8561 occupancy修改成功
# 8562 occupancy修改成功
# 8563 occupancy修改成功
# 8564 occupancy修改成功
# 8565 occupancy修改成功
# 8566 occupancy修改成功
# 8567 occupancy修改成功
# 8568 occupancy修改成功
# 8569 occupancy修改成功
# 8570 occupancy修改成功
# 8571 occupancy修改成功
# 8572 occupancy修改成功
# 8573 occupancy修改成功
# 8574 occupancy修改成功
# 8575 occupancy修改成功
# 8576 occupancy修改成功
# 8577 occupancy修改成功
# 8578 occupancy修改成功
# 8579 occupancy修改成功
# 8580 occupancy修改成功
# 8581 occupancy修改成功
# 8582 occupancy修改成功
# 8583 occupancy修改成功
# 8584 occupancy修改成功
# 8585 occupancy修改成功
# 8586 occupancy修改成功
#       Index_Num                  starttime resolution  speed  volume  \
# 0             3        2011-03-01T00:05:00    0:05:00    NaN     NaN
# 1             5        2011-03-01T00:10:00    0:05:00  61.91    11.0
# 2             8        2011-03-01T00:15:00    0:05:00    NaN     NaN
# 3             9        2011-03-01T00:20:00    0:05:00    NaN     NaN
# 4            12        2011-03-01T00:25:00    0:05:00    NaN     NaN
# ...         ...                        ...        ...    ...     ...
# 8582      17169  2011-03-30T23:40:00-07:00    0:05:00    NaN     5.0
# 8583      17170  2011-03-30T23:45:00-07:00    0:05:00    NaN     5.0
# 8584      17172  2011-03-30T23:50:00-07:00    0:05:00    NaN     5.0
# 8585      17175  2011-03-30T23:55:00-07:00    0:05:00    NaN     5.0
# 8586      17177  2011-03-31T00:00:00-07:00    0:05:00    NaN     5.0
#
#       occupancy
# 0           NaN
# 1          0.46
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 8582       0.36
# 8583       0.36
# 8584       0.36
# 8585       0.36
# 8586       0.36
#
# [8587 rows x 6 columns]

# %%
#显示data的相关信息
data.dtypes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8587 entries, 0 to 8586
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Index_Num   8587 non-null   int64
#  1   starttime   8587 non-null   object
#  2   resolution  8587 non-null   object
#  3   speed       8012 non-null   float64
#  4   volume      8301 non-null   float64
#  5   occupancy   8301 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 402.6+ KB

# %%
#各种统计量
# data.count() #计数方法count只记非nan值 (axis=1 按列)
# data.describe() #总统计值
# data.max() #最值、累加
# data.min()
# data.sum()
# data.quantile()  #中位数 quantile median
# data.median()   
# data.idxmax()  #最大值的索引值
# #data.argmax()#在0.21版本中删除了
# data.mad(axis=1)   #偏科程度（判断一组数据的最大值和最小值差别是不是很大）
# data.cumsum()  # 样本值累计和
# data.pct_change()  #变化率
# Out:
# starttime    2009-01-31T00:00:00
# speed                    142.738
# volume                   182.151
# occupancy                107.653
# dtype: object

# %% [markdown]
# #  画图

# %%
#建立一个专门为画图而生的dataframe
data_for_plot = data[['speed','volume','occupancy']]

# %%
# kind='bar'是柱形图，默认为line
data_for_plot.plot(kind='bar')
plt.show()

# %%
# 横柱形图
data_for_plot.plot(kind='barh')

# %%
# stacked=True堆叠
data_for_plot.plot(kind='bar',stacked=True)
plt.show()

# %%
#曲线覆盖面积图
data_for_plot.plot(kind='area')
plt.show()

# %%
# 画一行
data_for_plot.iloc[10].plot()
plt.show()

# %%
# 画10行
for i in range(10):
# for i in data.index:
    data_for_plot.iloc[i].plot(label=str(i))
plt.legend()
plt.show()

# %%
# 画一列
data_for_plot['speed'].plot()
plt.show()

# %%
# 转置画行
data_for_plot.T.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\mathematical_modeling\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# C:\ProgramData\Anaconda3\envs\mathematical_modeling\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\ProgramData\Anaconda3\envs\mathematical_modeling\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# C:\ProgramData\Anaconda3\envs\mathematical_modeling\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2089                     orientation=orientation,
#    2090                     bbox_inches_restore=_bbox_inches_restore,
# -> 2091                     **kwargs)
#    2092             finally:
#    2093                 if bbox_inches and restore_bbox:
#
# C:\ProgramData\Anaconda3\envs\mathematical_modeling\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# C:\ProgramData\Anaconda3\envs\mathematical_modeling\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     384         Draw the figure using the renderer.
#     385         """
# --> 386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
#     388             self.figure.draw(self.renderer)
#
# C:\ProgramData\Anaconda3\envs\mathematical_modeling\lib\site-packages\matplotlib\backends\backend_agg.py in get_renderer(self, cleared)
#     397                           and getattr(self, "_lastKey", None) == key)
#     398         if not reuse_renderer:
# --> 399             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     400             self._lastKey = key
#     401         elif cleared:
#
# C:\ProgramData\Anaconda3\envs\mathematical_modeling\lib\site-packages\matplotlib\backends\backend_agg.py in __init__(self, width, height, dpi)
#      84         self.width = width
#      85         self.height = height
# ---> 86         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      87         self._filter_renderers = []
#      88
#
# ValueError: Image size of 386x129547 pixels is too large. It must be less than 2^16 in each direction.

# %% [markdown]
# # 异常值去除

# %%
#先进行方差检验，若为零则进行阈值检验，若不为零则进行组合检验，然后进行方差检验
# #以最大值的百分之九十五为界限
# data.max() #最值、累加
# data['speed'].max()
# threshold_speed = data['speed'].max() * 0.95
# data.loc[data['speed'] >= threshold_speed]
from pandas import Series
s= pd.Series()
print(s,s.dtype)
for outliercount in range(2 , data.shape[0]):
#     print(outliercount)
#     tmp = data.loc[outliercount,["speed"]].values.astype(float) - data.loc[outliercount - 1,["speed"]].values.astype(float)
#     print(tmp,tmp.dtype)
    if ( (data.loc[outliercount,["speed"]].values.astype(float) - data.loc[outliercount-1,["speed"]].values.astype(float))**2 ==0 and 
        (data.loc[outliercount,["volume"]].values.astype(float) - data.loc[outliercount-1,["volume"]].values.astype(float))**2 ==0 and 
        (data.loc[outliercount,["occupancy"]].values.astype(float) - data.loc[outliercount-1,["occupancy"]].values.astype(float))**2 ==0) :
        #阈值检测设置速度：0-140；流量：0-225；占用率：0-100；
        if (0<= data.loc[outliercount,["speed"]].values <= 140) & (0<= data.loc[outliercount,["volume"]].values <= 225) & (0<= data.loc[outliercount,["occupancy"]].values <= 100) :#阈值检验
            pass
#             print("阈值检测通过") #阈值检测通过
        else : 
            s= s.append(Series([outliercount]))#添加该行标记到series，之后删除该行数据
            print("添加行", outliercount)
    elif ((data.loc[outliercount,["speed"]].values ==0 and data.loc[outliercount,["volume"]].values ==0 and data.loc[outliercount,["occupancy"]].values !=0) or 
            (data.loc[outliercount,["speed"]].values ==0 and data.loc[outliercount,["volume"]].values !=0 and data.loc[outliercount,["occupancy"]].values ==0) or 
            (data.loc[outliercount,["speed"]].values !=0 and data.loc[outliercount,["volume"]].values ==0 and data.loc[outliercount,["occupancy"]].values ==0) or 
            (data.loc[outliercount,["speed"]].values !=0 and data.loc[outliercount,["volume"]].values !=0 and data.loc[outliercount,["occupancy"]].values ==0) or 
            (data.loc[outliercount,["speed"]].values ==0 and data.loc[outliercount,["volume"]].values !=0 and data.loc[outliercount,["occupancy"]].values !=0)) :
        s= s.append(Series([outliercount])) #加该行标记到series，之后删除该行数据
        print("添加行", outliercount)
    else :
        #组合检验+阈值检验
        #组合检验（注意量纲）：（速度*1000/60）*（占用率*5）/（流量*5）=结果，结果：0-2038
        Combination_testing = (data.loc[outliercount,["speed"]].values*1000/60)*(data.loc[outliercount,["occupancy"]].values*5)/(data.loc[outliercount,["volume"]].values*5)
        if (0<= Combination_testing <=2038) :
            pass
#             print("组合检验通过") #组合检验通过
        else :
            s= s.append(Series([outliercount])) #添加该行标记到series，之后删除该行数据
        if (0<= data.loc[outliercount,["speed"]].values <= 140) & (0<= data.loc[outliercount,["volume"]].values <= 225) & (0<= data.loc[outliercount,["occupancy"]].values <= 100) :#阈值检验
            pass
#             print("阈值检测通过") #阈值检测通过
        else : 
            s= s.append(Series([outliercount])) #添加该行标记到series，之后删除该行数据
            print("添加行", outliercount)
s = s.astype('int')
s = s.sort_values(ascending=False)        
print(s)        
#删除对应列数据
print(data.shape[0])
data.drop(s,inplace=True) #根据S的编号删除
print(data.shape[0])
# Out:
# C:\ProgramData\Anaconda3\envs\mathematical_modeling\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# C:\ProgramData\Anaconda3\envs\mathematical_modeling\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in greater_equal
# C:\ProgramData\Anaconda3\envs\mathematical_modeling\lib\site-packages\ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in greater_equal
# Series([], dtype: float64) float64
# 添加行 2
# 添加行 3
# 添加行 4
# 添加行 5
# 添加行 6
# 添加行 7
# 添加行 8
# 添加行 9
# 添加行 10
# 添加行 11
# 添加行 12
# 添加行 13
# 添加行 14
# 添加行 15
# 添加行 16
# 添加行 17
# 添加行 18
# 添加行 19
# 添加行 20
# 添加行 21
# 添加行 22
# 添加行 23
# 添加行 24
# 添加行 25
# 添加行 26
# 添加行 27
# 添加行 28
# 添加行 29
# 添加行 30
# 添加行 31
# 添加行 32
# 添加行 33
# 添加行 34
# 添加行 35
# 添加行 36
# 添加行 37
# 添加行 38
# 添加行 39
# 添加行 40
# 添加行 41
# 添加行 42
# 添加行 43
# 添加行 44
# 添加行 45
# 添加行 46
# 添加行 47
# 添加行 48
# 添加行 49
# 添加行 50
# 添加行 51
# 添加行 52
# 添加行 53
# 添加行 54
# 添加行 55
# 添加行 56
# 添加行 57
# 添加行 58
# 添加行 59
# 添加行 60
# 添加行 61
# 添加行 62
# 添加行 63
# 添加行 64
# 添加行 65
# 添加行 66
# 添加行 67
# 添加行 68
# 添加行 69
# 添加行 70
# 添加行 71
# 添加行 72
# 添加行 73
# 添加行 74
# 添加行 75
# 添加行 76
# 添加行 77
# 添加行 78
# 添加行 79
# 添加行 80
# 添加行 81
# 添加行 82
# 添加行 83
# 添加行 84
# 添加行 85
# 添加行 86
# 添加行 87
# 添加行 88
# 添加行 89
# 添加行 90
# 添加行 91
# 添加行 92
# 添加行 93
# 添加行 94
# 添加行 95
# 添加行 96
# 添加行 97
# 添加行 98
# 添加行 99
# 添加行 100
# 添加行 101
# 添加行 102
# 添加行 103
# 添加行 104
# 添加行 105
# 添加行 106
# 添加行 107
# 添加行 108
# 添加行 109
# 添加行 110
# 添加行 111
# 添加行 112
# 添加行 113
# 添加行 114
# 添加行 115
# 添加行 116
# 添加行 117
# 添加行 118
# 添加行 119
# 添加行 120
# 添加行 121
# 添加行 122
# 添加行 123
# 添加行 124
# 添加行 125
# 添加行 126
# 添加行 127
# 添加行 128
# 添加行 129
# 添加行 130
# 添加行 131
# 添加行 132
# 添加行 133
# 添加行 134
# 添加行 135
# 添加行 136
# 添加行 137
# 添加行 138
# 添加行 139
# 添加行 140
# 添加行 141
# 添加行 142
# 添加行 143
# 添加行 144
# 添加行 145
# 添加行 146
# 添加行 147
# 添加行 148
# 添加行 149
# 添加行 150
# 添加行 151
# 添加行 152
# 添加行 153
# 添加行 154
# 添加行 155
# 添加行 156
# 添加行 157
# 添加行 158
# 添加行 159
# 添加行 160
# 添加行 161
# 添加行 162
# 添加行 163
# 添加行 164
# 添加行 165
# 添加行 166
# 添加行 167
# 添加行 168
# 添加行 169
# 添加行 170
# 添加行 171
# 添加行 172
# 添加行 173
# 添加行 174
# 添加行 175
# 添加行 176
# 添加行 177
# 添加行 178
# 添加行 179
# 添加行 180
# 添加行 181
# 添加行 182
# 添加行 183
# 添加行 184
# 添加行 185
# 添加行 186
# 添加行 187
# 添加行 188
# 添加行 189
# 添加行 190
# 添加行 191
# 添加行 192
# 添加行 193
# 添加行 194
# 添加行 195
# 添加行 196
# 添加行 197
# 添加行 198
# 添加行 199
# 添加行 200
# 添加行 201
# 添加行 202
# 添加行 203
# 添加行 204
# 添加行 205
# 添加行 206
# 添加行 207
# 添加行 208
# 添加行 209
# 添加行 210
# 添加行 211
# 添加行 212
# 添加行 213
# 添加行 214
# 添加行 215
# 添加行 216
# 添加行 217
# 添加行 218
# 添加行 219
# 添加行 220
# 添加行 221
# 添加行 222
# 添加行 223
# 添加行 224
# 添加行 225
# 添加行 226
# 添加行 227
# 添加行 228
# 添加行 229
# 添加行 230
# 添加行 231
# 添加行 232
# 添加行 233
# 添加行 234
# 添加行 235
# 添加行 236
# 添加行 237
# 添加行 238
# 添加行 239
# 添加行 240
# 添加行 241
# 添加行 242
# 添加行 243
# 添加行 244
# 添加行 245
# 添加行 246
# 添加行 247
# 添加行 248
# 添加行 249
# 添加行 250
# 添加行 251
# 添加行 252
# 添加行 253
# 添加行 254
# 添加行 255
# 添加行 256
# 添加行 257
# 添加行 258
# 添加行 259
# 添加行 260
# 添加行 261
# 添加行 262
# 添加行 263
# 添加行 264
# 添加行 265
# 添加行 266
# 添加行 267
# 添加行 268
# 添加行 269
# 添加行 270
# 添加行 271
# 添加行 272
# 添加行 273
# 添加行 274
# 添加行 275
# 添加行 276
# 添加行 277
# 添加行 278
# 添加行 279
# 添加行 280
# 添加行 281
# 添加行 282
# 添加行 283
# 添加行 284
# 添加行 285
# 添加行 286
# 添加行 292
# 添加行 294
# 添加行 300
# 添加行 301
# 添加行 302
# 添加行 303
# 添加行 304
# 添加行 307
# 添加行 308
# 添加行 309
# 添加行 311
# 添加行 312
# 添加行 313
# 添加行 315
# 添加行 316
# 添加行 320
# 添加行 322
# 添加行 323
# 添加行 326
# 添加行 327
# 添加行 334
# 添加行 577
# 添加行 584
# 添加行 587
# 添加行 589
# 添加行 592
# 添加行 594
# 添加行 597
# 添加行 600
# 添加行 602
# 添加行 603
# 添加行 609
# 添加行 621
# 添加行 623
# 添加行 624
# 添加行 1442
# 添加行 1444
# 添加行 1448
# 添加行 1455
# 添加行 1456
# 添加行 1457
# 添加行 1459
# 添加行 1460
# 添加行 1461
# 添加行 1462
# 添加行 1464
# 添加行 1468
# 添加行 1469
# 添加行 1470
# 添加行 1471
# 添加行 1473
# 添加行 1481
# 添加行 1487
# 添加行 1721
# 添加行 1722
# 添加行 1738
# 添加行 1742
# 添加行 1743
# 添加行 1744
# 添加行 1748
# 添加行 1749
# 添加行 1757
# 添加行 1760
# 添加行 1761
# 添加行 1762
# 添加行 1763
# 添加行 1764
# 添加行 1765
# 添加行 2007
# 添加行 2011
# 添加行 2013
# 添加行 2016
# 添加行 2019
# 添加行 2024
# 添加行 2025
# 添加行 2027
# 添加行 2037
# 添加行 2040
# 添加行 2042
# 添加行 2048
# 添加行 2049
# 添加行 2051
# 添加行 2055
# 添加行 2061
# 添加行 2293
# 添加行 2307
# 添加行 2315
# 添加行 2316
# 添加行 2318
# 添加行 2320
# 添加行 2321
# 添加行 2324
# 添加行 2327
# 添加行 2328
# 添加行 2329
# 添加行 2330
# 添加行 2334
# 添加行 2335
# 添加行 2337
# 添加行 2341
# 添加行 3172
# 添加行 3178
# 添加行 3179
# 添加行 3184
# 添加行 3185
# 添加行 3186
# 添加行 3195
# 添加行 3197
# 添加行 3199
# 添加行 3201
# 添加行 3202
# 添加行 3203
# 添加行 3205
# 添加行 3208
# 添加行 3215
# 添加行 3439
# 添加行 3443
# 添加行 3444
# 添加行 3445
# 添加行 3449
# 添加行 3452
# 添加行 3454
# 添加行 3455
# 添加行 3456
# 添加行 3457
# 添加行 3460
# 添加行 3461
# 添加行 3463
# 添加行 3468
# 添加行 3469
# 添加行 3715
# 添加行 3718
# 添加行 3722
# 添加行 3725
# 添加行 3729
# 添加行 3733
# 添加行 3734
# 添加行 3738
# 添加行 3745
# 添加行 3749
# 添加行 3750
# 添加行 3751
# 添加行 3755
# 添加行 4020
# 添加行 4021
# 添加行 4022
# 添加行 4025
# 添加行 4027
# 添加行 4028
# 添加行 4029
# 添加行 4031
# 添加行 4032
# 添加行 4035
# 添加行 4039
# 添加行 4042
# 添加行 4045
# 添加行 4046
# 添加行 4049
# 添加行 4289
# 添加行 4302
# 添加行 4306
# 添加行 4309
# 添加行 4310
# 添加行 4313
# 添加行 4315
# 添加行 4319
# 添加行 4320
# 添加行 4323
# 添加行 4584
# 添加行 4592
# 添加行 4604
# 添加行 4605
# 添加行 4611
# 添加行 4613
# 添加行 4614
# 添加行 4617
# 添加行 4618
# 添加行 4624
# 添加行 4627
# 添加行 4628
# 添加行 4871
# 添加行 4879
# 添加行 4894
# 添加行 4897
# 添加行 4898
# 添加行 4899
# 添加行 4903
# 添加行 4906
# 添加行 4907
# 添加行 4908
# 添加行 4919
# 添加行 4921
# 添加行 4924
# 添加行 4926
# 添加行 5172
# 添加行 5177
# 添加行 5178
# 添加行 5180
# 添加行 5181
# 添加行 5182
# 添加行 5186
# 添加行 5187
# 添加行 5188
# 添加行 5191
# 添加行 5192
# 添加行 5196
# 添加行 5198
# 添加行 5200
# 添加行 5202
# 添加行 5204
# 添加行 5206
# 添加行 5207
# 添加行 5209
# 添加行 5210
# 添加行 5216
# 添加行 5218
# 添加行 5219
# 添加行 5220
# 添加行 5232
# 添加行 5442
# 添加行 5446
# 添加行 5447
# 添加行 5450
# 添加行 5458
# 添加行 5459
# 添加行 5462
# 添加行 5465
# 添加行 5466
# 添加行 5467
# 添加行 5468
# 添加行 5469
# 添加行 5472
# 添加行 5473
# 添加行 5474
# 添加行 5475
# 添加行 5477
# 添加行 5480
# 添加行 5483
# 添加行 5484
# 添加行 5485
# 添加行 5490
# 添加行 5495
# 添加行 5558
# 添加行 5730
# 添加行 5737
# 添加行 5748
# 添加行 5749
# 添加行 5750
# 添加行 5751
# 添加行 5752
# 添加行 5753
# 添加行 5755
# 添加行 5756
# 添加行 5759
# 添加行 5760
# 添加行 5781
# 添加行 6018
# 添加行 6022
# 添加行 6023
# 添加行 6025
# 添加行 6028
# 添加行 6031
# 添加行 6035
# 添加行 6037
# 添加行 6045
# 添加行 6048
# 添加行 6052
# 添加行 6055
# 添加行 6058
# 添加行 6060
# 添加行 6063
# 添加行 6312
# 添加行 6313
# 添加行 6314
# 添加行 6317
# 添加行 6318
# 添加行 6324
# 添加行 6326
# 添加行 6332
# 添加行 6333
# 添加行 6335
# 添加行 6338
# 添加行 6342
# 添加行 6347
# 添加行 6349
# 添加行 6576
# 添加行 6585
# 添加行 6587
# 添加行 6589
# 添加行 6590
# 添加行 6591
# 添加行 6592
# 添加行 6594
# 添加行 6595
# 添加行 6597
# 添加行 6602
# 添加行 6603
# 添加行 6605
# 添加行 6606
# 添加行 6607
# 添加行 6608
# 添加行 6610
# 添加行 6612
# 添加行 6613
# 添加行 6614
# 添加行 6615
# 添加行 6616
# 添加行 6618
# 添加行 6620
# 添加行 6621
# 添加行 6626
# 添加行 6730
# 添加行 6864
# 添加行 6872
# 添加行 6874
# 添加行 6877
# 添加行 6878
# 添加行 6888
# 添加行 6889
# 添加行 6893
# 添加行 6899
# 添加行 6901
# 添加行 6902
# 添加行 6905
# 添加行 6906
# 添加行 6908
# 添加行 6910
# 添加行 7201
# 添加行 7203
# 添加行 7205
# 添加行 7206
# 添加行 7209
# 添加行 7210
# 添加行 7211
# 添加行 7213
# 添加行 7215
# 添加行 7217
# 添加行 7218
# 添加行 7223
# 添加行 7225
# 添加行 7226
# 添加行 7232
# 添加行 7436
# 添加行 7437
# 添加行 7441
# 添加行 7442
# 添加行 7443
# 添加行 7446
# 添加行 7447
# 添加行 7453
# 添加行 7455
# 添加行 7456
# 添加行 7458
# 添加行 7461
# 添加行 7462
# 添加行 7465
# 添加行 7467
# 添加行 7468
# 添加行 7469
# 添加行 7470
# 添加行 7471
# 添加行 7472
# 添加行 7474
# 添加行 7475
# 添加行 7476
# 添加行 7478
# 添加行 7479
# 添加行 7480
# 添加行 7482
# 添加行 7483
# 添加行 7484
# 添加行 7485
# 添加行 7486
# 添加行 8289
# 添加行 8296
# 添加行 8298
# 添加行 8299
# 添加行 8300
# 添加行 8301
# 添加行 8302
# 添加行 8303
# 添加行 8304
# 添加行 8305
# 添加行 8306
# 添加行 8307
# 添加行 8308
# 添加行 8309
# 添加行 8310
# 添加行 8311
# 添加行 8312
# 添加行 8313
# 添加行 8314
# 添加行 8315
# 添加行 8316
# 添加行 8317
# 添加行 8318
# 添加行 8319
# 添加行 8320
# 添加行 8321
# 添加行 8322
# 添加行 8323
# 添加行 8324
# 添加行 8325
# 添加行 8326
# 添加行 8327
# 添加行 8328
# 添加行 8329
# 添加行 8330
# 添加行 8331
# 添加行 8332
# 添加行 8333
# 添加行 8334
# 添加行 8335
# 添加行 8336
# 添加行 8337
# 添加行 8338
# 添加行 8339
# 添加行 8340
# 添加行 8341
# 添加行 8342
# 添加行 8343
# 添加行 8344
# 添加行 8345
# 添加行 8346
# 添加行 8347
# 添加行 8348
# 添加行 8349
# 添加行 8350
# 添加行 8351
# 添加行 8352
# 添加行 8353
# 添加行 8354
# 添加行 8355
# 添加行 8356
# 添加行 8357
# 添加行 8358
# 添加行 8359
# 添加行 8360
# 添加行 8361
# 添加行 8362
# 添加行 8363
# 添加行 8364
# 添加行 8365
# 添加行 8366
# 添加行 8367
# 添加行 8368
# 添加行 8369
# 添加行 8370
# 添加行 8371
# 添加行 8372
# 添加行 8373
# 添加行 8374
# 添加行 8375
# 添加行 8376
# 添加行 8377
# 添加行 8378
# 添加行 8379
# 添加行 8380
# 添加行 8381
# 添加行 8382
# 添加行 8383
# 添加行 8384
# 添加行 8385
# 添加行 8386
# 添加行 8387
# 添加行 8388
# 添加行 8389
# 添加行 8390
# 添加行 8391
# 添加行 8392
# 添加行 8393
# 添加行 8394
# 添加行 8395
# 添加行 8396
# 添加行 8397
# 添加行 8398
# 添加行 8399
# 添加行 8400
# 添加行 8401
# 添加行 8402
# 添加行 8403
# 添加行 8404
# 添加行 8405
# 添加行 8406
# 添加行 8407
# 添加行 8408
# 添加行 8409
# 添加行 8410
# 添加行 8411
# 添加行 8412
# 添加行 8413
# 添加行 8414
# 添加行 8415
# 添加行 8416
# 添加行 8417
# 添加行 8418
# 添加行 8419
# 添加行 8420
# 添加行 8421
# 添加行 8422
# 添加行 8423
# 添加行 8424
# 添加行 8425
# 添加行 8426
# 添加行 8427
# 添加行 8428
# 添加行 8429
# 添加行 8430
# 添加行 8431
# 添加行 8432
# 添加行 8433
# 添加行 8434
# 添加行 8435
# 添加行 8436
# 添加行 8437
# 添加行 8438
# 添加行 8439
# 添加行 8440
# 添加行 8441
# 添加行 8442
# 添加行 8443
# 添加行 8444
# 添加行 8445
# 添加行 8446
# 添加行 8447
# 添加行 8448
# 添加行 8449
# 添加行 8450
# 添加行 8451
# 添加行 8452
# 添加行 8453
# 添加行 8454
# 添加行 8455
# 添加行 8456
# 添加行 8457
# 添加行 8458
# 添加行 8459
# 添加行 8460
# 添加行 8461
# 添加行 8462
# 添加行 8463
# 添加行 8464
# 添加行 8465
# 添加行 8466
# 添加行 8467
# 添加行 8468
# 添加行 8469
# 添加行 8470
# 添加行 8471
# 添加行 8472
# 添加行 8473
# 添加行 8474
# 添加行 8475
# 添加行 8476
# 添加行 8477
# 添加行 8478
# 添加行 8479
# 添加行 8480
# 添加行 8481
# 添加行 8482
# 添加行 8483
# 添加行 8484
# 添加行 8485
# 添加行 8486
# 添加行 8487
# 添加行 8488
# 添加行 8489
# 添加行 8490
# 添加行 8491
# 添加行 8492
# 添加行 8493
# 添加行 8494
# 添加行 8495
# 添加行 8496
# 添加行 8497
# 添加行 8498
# 添加行 8499
# 添加行 8500
# 添加行 8501
# 添加行 8502
# 添加行 8503
# 添加行 8504
# 添加行 8505
# 添加行 8506
# 添加行 8507
# 添加行 8508
# 添加行 8509
# 添加行 8510
# 添加行 8511
# 添加行 8512
# 添加行 8513
# 添加行 8514
# 添加行 8515
# 添加行 8516
# 添加行 8517
# 添加行 8518
# 添加行 8519
# 添加行 8520
# 添加行 8521
# 添加行 8522
# 添加行 8523
# 添加行 8524
# 添加行 8525
# 添加行 8526
# 添加行 8527
# 添加行 8528
# 添加行 8529
# 添加行 8530
# 添加行 8531
# 添加行 8532
# 添加行 8533
# 添加行 8534
# 添加行 8535
# 添加行 8536
# 添加行 8537
# 添加行 8538
# 添加行 8539
# 添加行 8540
# 添加行 8541
# 添加行 8542
# 添加行 8543
# 添加行 8544
# 添加行 8545
# 添加行 8546
# 添加行 8547
# 添加行 8548
# 添加行 8549
# 添加行 8550
# 添加行 8551
# 添加行 8552
# 添加行 8553
# 添加行 8554
# 添加行 8555
# 添加行 8556
# 添加行 8557
# 添加行 8558
# 添加行 8559
# 添加行 8560
# 添加行 8561
# 添加行 8562
# 添加行 8563
# 添加行 8564
# 添加行 8565
# 添加行 8566
# 添加行 8567
# 添加行 8568
# 添加行 8569
# 添加行 8570
# 添加行 8571
# 添加行 8572
# 添加行 8573
# 添加行 8574
# 添加行 8575
# 添加行 8576
# 添加行 8577
# 添加行 8578
# 添加行 8579
# 添加行 8580
# 添加行 8581
# 添加行 8582
# 添加行 8583
# 添加行 8584
# 添加行 8585
# 添加行 8586
# 0    8586
# 0    8586
# 0    8585
# 0    8585
# 0    8584
#      ...
# 0       4
# 0       3
# 0       3
# 0       2
# 0       2
# Length: 1524, dtype: int32
# 8587
# 7637

# %% [markdown]
# # 保存数据

# %%
data.to_csv('data 3_change.csv')      #写入csv文件

# %%
print(data.shape[0])
data.drop(s,inplace=True)
# for i in range(s.shape[0]):
#     print(s[])
#     data.drop()

print(data.shape[0])
# Out:
# 8635
# 8522

# %% [markdown]
# # 是否显示全部print数据

# %%
#显示所有列
pd.set_option('display.max_columns', None)
#显示所有行
pd.set_option('display.max_rows', None)
#设置value的显示长度为100，默认为50

print(s,s.dtype)
# Out:
# 0    8404
# 0    8373
# 0    8003
# 0    7792
# 0    7792
# 0    7772
# 0    7769
# 0    7481
# 0    7211
# 0    6962
# 0    6943
# 0    6902
# 0    6867
# 0    6626
# 0    6176
# 0    6066
# 0    5198
# 0    4769
# 0    4621
# 0    4064
# 0    3194
# 0    3193
# 0    3192
# 0    3016
# 0    3015
# 0    3014
# 0    2992
# 0    2991
# 0    2990
# 0    2989
# 0    2988
# 0    2987
# 0    2986
# 0    2985
# 0    2984
# 0    2983
# 0    2982
# 0    2981
# 0    2980
# 0    2965
# 0    2964
# 0    2962
# 0    2961
# 0    2959
# 0    2958
# 0    2956
# 0    2955
# 0    2954
# 0    2952
# 0    2951
# 0    2950
# 0    2949
# 0    2948
# 0    2947
# 0    2946
# 0    2945
# 0    2944
# 0    2943
# 0    2942
# 0    2941
# 0    2940
# 0    2939
# 0    2938
# 0    2937
# 0    2936
# 0    2935
# 0    2934
# 0    2933
# 0    2932
# 0    2931
# 0    2930
# 0    2929
# 0    2928
# 0    2927
# 0    2926
# 0    2925
# 0    2924
# 0    2921
# 0    2920
# 0    2919
# 0    2918
# 0    2917
# 0    2916
# 0    2915
# 0    2914
# 0    2913
# 0    2911
# 0    2908
# 0    2907
# 0    2906
# 0    2905
# 0    2904
# 0    2857
# 0    2613
# 0    2350
# 0    2331
# 0    2126
# 0    2079
# 0    2054
# 0    2053
# 0    2052
# 0    2029
# 0    2025
# 0    1679
# 0    1147
# 0    1146
# 0    1145
# 0    1144
# 0    1144
# 0    1143
# 0    1142
# 0    1142
# 0    1141
# 0    1140
# 0      39
# 0       2
# 0       2
# dtype: int32 int32

# %%
speedtmp = data.loc[9,["speed"]]
print(speedtmp)
# Out:
# speed    121.740294
# Name: 9, dtype: object

# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output


n = 10
a = np.zeros((n, n))
plt.figure()

for i in range(n):
    plt.imshow(a)
    plt.show()
    a[i, i] = 1
    clear_output(wait=True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib inline
# %matplotlib widget
import matplotlib.pyplot as plt
plt.figure()
x = [1,2,3]
y = [4,5,6]
plt.plot(x,y)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import sys
sys.path   #查看导入包的路径
sys.executable  #查看使用kernel的路径
# Out:
# 'C:\\ProgramData\\Anaconda3\\envs\\mathematical_modeling\\python.exe'
